# %% [markdown]
# **Import Python Packages**

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import pathlib
import matplotlib.pyplot as plt
import maup
import requests

# %% [markdown]
# **Import Demographic Data**
# Use Census API and provided data from []

# %% [markdown]
# Retrieve block level data for the state using state fips code from census API, retrieves from appropriate
# columns in GEOID, convert to .csv to easily manipulate individual state data

# %%
#Use code to read the csv so you do not need to retrieve the data and create a csv every time you run the script

# %%
#Retrieve block shapefiles

# %%
#Set/confirm shapefile projections by comparing precinct shapefile and block level shapefile, 
#converting them to match

# %% [markdown]
# **Join data with shape (block level demographic data with block level shapefile)**

# %% [markdown]
# **Prorate demographic and Voting Population data from census block level to precinct level**

# %% [markdown]
# **Import 2016 Election Data**

# %% [markdown]
# Shape Files (gdf)

# %%
#Precinct and congressional district shapefiles from State of MI GIS portal
precincts_shp_2016 = gpd.read_file("2016_Voting_Precincts-shp/2016_Voting_Precincts.shp")
#voting_precincts_shp_2016.plot()

#Why do we need anything other than 2016 voting precincts for our purposes?
#----------------------------------------------------
#Voting Tabulation District shp from Census 2010 data
vtd_2012 = gpd.read_file("tl_2012_26_vtd10/tl_2012_26_vtd10.shp")
#vtd_2012.plot()

###Note: Lily imported because CG had imported... The MGGG shp does not use state senate or house
### so I am not sure why it is included in the datapackage bundle?
#State Senate
state_senate = gpd.read_file("tl_2011_26_sldu/tl_2011_26_sldu.shp")

#State House of Representatives
state_house = gpd.read_file("tl_2011_26_sldl/tl_2011_26_sldl.shp")

# %%
precincts_shp_2016.head()
# Out:
#    OBJECTID    Id        VTD2016 CountyFips Jurisdicti  ElectionYe  \
# 0         1  3888  1632100000001        163      21000        2016
# 1         2  3889  1632100000002        163      21000        2016
# 2         3  3890  1632100000003        163      21000        2016
# 3         4  3891  1632100000004        163      21000        2016
# 4         5  3892  1632100000005        163      21000        2016
#
#               Label    ShapeSTAre   ShapeSTLen  \
# 0  City of Dearborn  2.489738e+06  6846.254657
# 1  City of Dearborn  1.058362e+06  4621.388992
# 2  City of Dearborn  1.488846e+06  4909.715171
# 3  City of Dearborn  1.187165e+06  4354.743602
# 4  City of Dearborn  1.133548e+06  5460.202887
#
#                                             geometry
# 0  POLYGON ((734740.564 203392.197, 734729.230 20...
# 1  POLYGON ((733757.240 203553.421, 733767.280 20...
# 2  POLYGON ((733220.680 203094.269, 733125.455 20...
# 3  POLYGON ((732401.480 203234.816, 732303.854 20...
# 4  POLYGON ((731590.226 203387.835, 731604.080 20...

# %%
#To select things for single county... Mask = series that is T or F for every index. County Fips for Alleghan County (ex. where there is a ward) = "026005"
foo = precincts_shp_2016[(precincts_shp_2016.CountyFips == "005")
                   &(precincts_shp_2016.Label.str.contains("Holland"))]
#foo = filter for City of Holland

# %%
#Make column for ward, precinct, Label/city
#For alleghan county ex, need to cut off 9, 11, 12, 13 - use foo to capture last 3 digits
foo.VTD2016
bar = "0053864004009"

# %%
#bar3 = bar[-3:]

# %%
#bar3.strip("0")

# %%
def get_precinct_number(VTD2016):
    last_3 = VTD2016[-3:] 
    return last_3.lstrip("0")

# %%
#x = get_precinct_number('010')
#print(x)

# %%
#apply function uses dataframe.apply(func, axis=0, raw=False, result_type=None, args=(), **kwds)
#foo.VTD2016.apply(get_precinct_number)

# %%
#def strip_zeros(precinct_number):
 #   return precinct_number.strip("0")

# %%
#Trash:
#goo = precincts_shp_2016[(precincts_shp_2016.VTD2016.str.apply(get_precinct_number))
 #                        &(precincts_shp_2016.VTD2016.str.apply(strip_precinct_zeros))]

# %%
#foo.VTD2016.apply(strip_zeros)

# %%
def get_ward(VTD2016):
    ward = VTD2016[-5:-3].lstrip("0")
    return ward

# %%
foo.VTD2016.apply(get_ward)
# Out:
# 86    4
# 87    5
# 88    5
# 89    5
# Name: VTD2016, dtype: object

# %%
# gdf = precincts_shp_2016
# gdf['precinct_number'] = gdf['VTD2016'].apply(get_precinct_number)
# gdf['ward_number'] = gdf['VTD2016'].apply(get_ward)
# gdf.head()

# %%
# #Step 1
# def new_label(label):
#    # for x in gdf.Label: - - - Will be faster if I do not use for loop so that it does not iterate through the thousands of items
#     #if gdf.Label.str.contains('City of'):
#             #old_string = gdf.Label.str.contains('City of')
#             #replace_string = old_string.replace("City of", "")
            
#             #elif gdf.Label.str.contains('Township')
#             #^cannot apply str bc it is already a str, cant apply contains() bc that is for a list of strings
            
#     if 'City of' in label:
#         replace_label = label.replace("City of", "")
#         replace_label = replace_label + " City"
        
#     elif 'Township' in label:
#         replace_label = label
        
#     return replace_label
# #-------------------------------- 
# #Step 2
# def get_ward(VTD2016):
#     ward = VTD2016[-5:-3].lstrip("0")
#     return ward
# def add_ward(VTD2016):
#     ward = VTD2016[-5, -3]
#     if ward != 0:
#         replace_label = replace_label + "; Ward " + ward_num
#     elif ward == 0:
#         replace_label = replace_label
#     return replace_label
   #Need to modify the Label call to reflect the updated labels after city/twp changed  precincts_shp_2016.Label     
     
# combine to use multiple variables:
def precinct_mod(row):
    label = row['Label']
    vtd2016 = row['VTD2016']
    
    if 'City of' in label:
        replace_label = label.replace("City of", "")
        replace_label = replace_label + " City"
        
    elif 'Township' in label:
        replace_label = label
        
    ward = vtd2016[-5:-3]
    precinct_num = vtd2016[-3:].lstrip("0")
    if ward != '00':
        ward = ward.lstrip("0")
        replace_label = replace_label + "; Ward " + ward + "; Precinct " + precinct_num
    elif ward == '00':
        replace_label = replace_label + "; " + precinct_num
    return replace_label

# %%
#foo.Label.apply(new_label)
#foo.apply(precinct_mod, axis = 1)
precincts_shp_2016.apply(precinct_mod, axis = 1)
# Out:
# 0         Dearborn City; 1
# 1         Dearborn City; 2
# 2         Dearborn City; 3
# 3         Dearborn City; 4
# 4         Dearborn City; 5
#                ...
# 4805     Genoa Township; 7
# 4806    Oceola Township; 5
# 4807    Oceola Township; 1
# 4808    Oceola Township; 2
# 4809    Oceola Township; 4
# Length: 4810, dtype: object

# %%
gdf = precincts_shp_2016
gdf['precinct'] = gdf.apply(precinct_mod, axis = 1)
gdf.head()
# Out:
#    OBJECTID    Id        VTD2016 CountyFips Jurisdicti  ElectionYe  \
# 0         1  3888  1632100000001        163      21000        2016
# 1         2  3889  1632100000002        163      21000        2016
# 2         3  3890  1632100000003        163      21000        2016
# 3         4  3891  1632100000004        163      21000        2016
# 4         5  3892  1632100000005        163      21000        2016
#
#               Label    ShapeSTAre   ShapeSTLen  \
# 0  City of Dearborn  2.489738e+06  6846.254657
# 1  City of Dearborn  1.058362e+06  4621.388992
# 2  City of Dearborn  1.488846e+06  4909.715171
# 3  City of Dearborn  1.187165e+06  4354.743602
# 4  City of Dearborn  1.133548e+06  5460.202887
#
#                                             geometry           precinct
# 0  POLYGON ((734740.564 203392.197, 734729.230 20...   Dearborn City; 1
# 1  POLYGON ((733757.240 203553.421, 733767.280 20...   Dearborn City; 2
# 2  POLYGON ((733220.680 203094.269, 733125.455 20...   Dearborn City; 3
# 3  POLYGON ((732401.480 203234.816, 732303.854 20...   Dearborn City; 4
# 4  POLYGON ((731590.226 203387.835, 731604.080 20...   Dearborn City; 5

# %%
df.head()
# Out:
#          county_name               precinct      votes                    \
# party                                       democratic green libertarian
# 0      Alcona County     ALCONA TOWNSHIP; 1        199     2          13
# 1      Alcona County  CALEDONIA TOWNSHIP; 1        178     4          14
# 2      Alcona County     CURTIS TOWNSHIP; 1        214    13           8
# 3      Alcona County  GREENBUSH TOWNSHIP; 1        256     4          22
# 4      Alcona County     GUSTIN TOWNSHIP; 1         80     6          16
#
#
# party republican
# 0            500
# 1            441
# 2            401
# 3            501
# 4            249

# %%
# intersect = list(set(gdf.precinct) & set(df.precinct))
# intersect
gdf_set = set(gdf.precinct.str.lower().unique())
df_set = set(df.precinct.str.lower().unique())
difference = df_set.symmetric_difference(gdf_set)
intersection = gdf_set.intersection(df_set)

# %%
df.set
difference
# Out:
# {' warren city; ward 2; precinct 41',
#  'st. clair shores city; 8',
#  ' flint city; ward 2; precinct 11',
#  ' southfield city; 26',
#  'charter township of bloomfield; 28',
#  ' garden city city; 1',
#  'portland city; 2',
#  'farmington hills city; 6',
#  ' escanaba city; 1',
#  ' detroit city; ward 1; precinct 362',
#  ' royal oak city; 1',
#  'detroit city; 393',
#  ' detroit city; ward 6; precinct 157',
#  'charter township of bloomfield; 2',
#  ' kalamazoo city; 7',
#  ' mt clemens city; 3',
#  ' portage city; 4',
#  ' roseville city; 5',
#  'royal oak city; 23',
#  ' sterling heights city; 14',
#  'reed city; 1',
#  ' westland city; 19',
#  ' east lansing city; 6',
#  'dearborn heights city; 20',
#  'grand rapids city; ward 2; precinct 38',
#  ' muskegon city; ward 4; precinct 13',
#  'cheboygan city; 2',
#  ' flint city; ward 5; precinct 62',
#  'detroit city; 4',
#  'woodhaven city; 1',
#  ' grandville city; 3',
#  'potterville city; 1',
#  'midland city; ward 2; precinct 2',
#  'romulus city; 8',
#  ' grand rapids city; ward 1; precinct 1',
#  'dearborn city; 30',
#  ' taylor city; 3',
#  'wixom city; 4',
#  ' sterling heights city; 35',
#  'charter township of bloomfield; 32',
#  'st. joseph township; 4',
#  'ann arbor city; ward 4; precinct 1',
#  'detroit city; 901|avcb',
#  'charter township of milford; 6',
#  ' highland park city; 20',
#  ' livonia city; 11a',
#  'roseville city; 15',
#  ' ann arbor city; ward 2; precinct 2',
#  ' detroit city; ward 2; precinct 208',
#  'ludington city; ward 6; precinct 1',
#  'detroit city; 402',
#  'pontiac city; ward 5; precinct 13',
#  ' harbor springs city; 1',
#  ' white cloud city; 1',
#  'flint city; ward 6; precinct 44',
#  'allen park city; 9',
#  'detroit city; 272',
#  ' petoskey city; ward 1; precinct 1',
#  ' battle creek city; ward 2; precinct 7',
#  'oak park city; 16',
#  'pontiac city; ward 1; precinct 3',
#  'eaton rapids city; 2',
#  ' kentwood city; ward 1; precinct 5',
#  ' detroit city; ward 1; precinct 277',
#  'grand rapids city; ward 1; precinct 22',
#  ' farmington hills city; 12',
#  ' farmington hills city; 10',
#  'warren city; ward 1; precinct 1',
#  'oxford township; 4',
#  'east grand rapids city; ward 2; precinct 3',
#  'rochester hills city; ward 1; precinct 19',
#  'charter township of waterford; 17',
#  ' flint city; ward 1; precinct 3',
#  'charter township of brandon; 3',
#  ' hudsonville city; ward 1; precinct 1',
#  'east lansing city; 5',
#  'detroit city; 220',
#  'battle creek city; 7',
#  ' detroit city; ward 3; precinct 183',
#  ' ferrysburg city; 1',
#  ' grand rapids city; ward 2; precinct 47',
#  ' port huron city; 7',
#  'charter township of waterford; 28',
#  'st. clair township; 2',
#  'port huron city; 6',
#  'detroit city; 252',
#  'detroit city; 320',
#  'charter township of commerce; 13',
#  'dearborn city; 21',
#  ' roosevelt park city; 1',
#  'portage city; 3',
#  ' richmond city; 2',
#  'grand rapids city; ward 2; precinct 45',
#  'roseville city; 6',
#  'de witt township; 4',
#  ' kentwood city; ward 2; precinct 11',
#  ' detroit city; ward 6; precinct 471',
#  'livonia city; 19|a',
#  'detroit city; 386',
#  'detroit city; 341',
#  'independence township; 7',
#  ' detroit city; ward 2; precinct 235',
#  ' midland city; ward 1; precinct 3',
#  'lansing city; ward 2; precinct 15',
#  ' oak park city; 1',
#  ' detroit city; ward 5; precinct 163',
#  ' detroit city; ward 2; precinct 313',
#  'dearborn heights city; 9',
#  ' detroit city; ward 7; precinct 374',
#  'midland city; ward 5; precinct 3',
#  'wyoming city; ward 2; precinct 19',
#  'detroit city; 367',
#  ' battle creek city; ward 1; precinct 22',
#  ' sterling heights city; 42',
#  ' hazel park city; 4',
#  'detroit city; 471',
#  'southfield city; 11',
#  ' livonia city; 10a',
#  'flat rock city; 3',
#  'charter township of highland; 8',
#  'charter township of lyon; 5',
#  'beaverton city; 1',
#  'st. clair shores city; 2',
#  'orion township; 14',
#  'ypsilanti city; ward 3; precinct 2',
#  ' east lansing city; 17',
#  ' owosso city; ward 1; precinct 1',
#  ' detroit city; ward 7; precinct 408',
#  ' detroit city; ward 6; precinct 480',
#  'port huron city; 909|avcb',
#  ' westland city; 34',
#  ' iron river city; 4',
#  'grandville city; 1',
#  ' dearborn city; 42',
#  'warren city; ward 5; precinct 8',
#  ' hastings city; ward 10; precinct 1',
#  ' lincoln park city; 6',
#  'lansing city; ward 2; precinct 21',
#  ' roseville city; 3',
#  'royal oak city; 17',
#  ' kalamazoo city; 11',
#  ' detroit city; ward 3; precinct 77',
#  ' burton city; 9',
#  ' grand rapids city; ward 2; precinct 27',
#  ' westland city; 30',
#  'coleman city; 1',
#  'port huron city; 906|avcb',
#  'holly township; 2',
#  'township of holly; 2',
#  'grosse pointe farms city; 4',
#  'holland city; ward 4; precinct 9',
#  'livonia city; 31|a',
#  'springfield township; 3',
#  'eastpointe city; 1',
#  'owosso city; ward 2; precinct 4',
#  ' manistique city; 2',
#  'taylor city; 21',
#  ' novi city; 8',
#  'warren city; ward 3; precinct 11',
#  'southfield city; 19',
#  'detroit city; 946|avcb',
#  'norton shores city; ward 2; precinct 7',
#  'dearborn city; 7',
#  ' detroit city; ward 1; precinct 271',
#  'detroit city; 279',
#  ' ann arbor city; ward 4; precinct 2',
#  ' troy city; 18',
#  'owosso city; ward 2; precinct 3',
#  'kentwood city; ward 2; precinct 13',
#  ' grand rapids city; ward 1; precinct 9',
#  'manistee city; 1',
#  'rose township; 3',
#  ' ecorse city; 7',
#  ' gaylord city; ward 3; precinct 1',
#  ' detroit city; ward 5; precinct 116',
#  'wyoming city; ward 1; precinct 3',
#  'west bloomfield township; 4',
#  'dearborn city; 40',
#  'muskegon city; ward 2; precinct 6',
#  ' detroit city; ward 4; precinct 56',
#  ' farmington hills city; 19',
#  ' rochester hills city; ward 1; precinct 14',
#  'detroit city; 97',
#  ' detroit city; ward 3; precinct 75',
#  'brandon township; 5',
#  ' warren city; ward 3; precinct 32',
#  ' warren city; ward 4; precinct 16',
#  ' belleville city; 1',
#  'west bloomfield township; 14',
#  'ionia city; ward 4; precinct 4',
#  ' st clair city; 2',
#  ' omer city; ward 1; precinct 1',
#  'detroit city; 14',
#  'bay city; ward 9; precinct 1',
#  'eastpointe city; 8',
#  'detroit city; 126',
#  'grandville city; 5',
#  ' southfield city; 35',
#  ' wyoming city; ward 1; precinct 1',
#  'marysville city; 902|avcb',
#  'melvindale city; 1',
#  ' detroit city; ward 5; precinct 443',
#  'flushing city; 2',
#  'bloomfield township; 15',
#  'pontiac city; ward 2; precinct 5',
#  'waterford township; 13',
#  'rochester city; 2',
#  ' south lyon city; 2',
#  'ann arbor city; ward 2; precinct 1',
#  'inkster city; ward 3; precinct 2',
#  ' pinconning city; 1',
#  'charter township of independence; 5',
#  ' flint city; ward 5; precinct 28',
#  'dearborn city; 42',
#  'troy city; 18',
#  'charter township of west bloomfield; 23',
#  ' grand rapids city; ward 1; precinct 7',
#  ' harrison city; 1',
#  ' east lansing city; 14',
#  'detroit city; 203',
#  ' detroit city; ward 7; precinct 332',
#  ' sterling heights city; 45',
#  ' garden city city; 3',
#  ' westland city; 12',
#  ' marquette city; 6',
#  'pontiac city; ward 4; precinct 12',
#  ' flint city; ward 9; precinct 61',
#  'charter township of springfield; 5',
#  'detroit city; 360',
#  'ontwa township; 901|avcb',
#  'rochester city; 1',
#  'rochester hills city; ward 1; precinct 3',
#  ' lansing city; ward 2; precinct 14',
#  ' sterling heights city; 25',
#  'detroit city; 183',
#  'taylor city; 7',
#  ' flat rock city; 1',
#  'plymouth city; 3',
#  'richmond city; 2',
#  ' st joseph city; 2',
#  ' gladwin city; ward 1; precinct 1',
#  ' lincoln park city; 22',
#  'ann arbor city; ward 4; precinct 2',
#  'charter township of royal oak; 1',
#  'grand rapids city; ward 1; precinct 18',
#  'detroit city; 75',
#  'ecorse city; 5',
#  ' detroit city; ward 1; precinct 272',
#  ' burton city; 12',
#  ' flint city; ward 3; precinct 18',
#  ' southfield city; 11',
#  'la grange township; 1',
#  'warren city; ward 5; precinct 3',
#  ' detroit city; ward 2; precinct 260',
#  ' grand rapids city; ward 2; precinct 35',
#  'charter township of commerce; 2',
#  ' inkster city; ward 1; precinct 1',
#  ' oak park city; 11',
#  'grosse pointe farms city; 3',
#  'warren city; ward 5; precinct 18',
#  'detroit city; 245',
#  'saginaw city; 8',
#  ' mt pleasant city; 7',
#  ' detroit city; ward 4; precinct 23',
#  'southgate city; 5',
#  ' troy city; 29',
#  'dearborn city; 2',
#  'troy city; 31',
#  'detroit city; 150',
#  ' walker city; ward 3; precinct 7',
#  'charter township of west bloomfield; 19',
#  'allen park city; 3',
#  'dowagiac city; 1',
#  ' royal oak city; 16',
#  ' grand rapids city; ward 3; precinct 61',
#  ' davison city; 1',
#  'waterford township; 5',
#  ' grand rapids city; ward 2; precinct 25',
#  ' marquette city; 5',
#  'kalamazoo city; 13',
#  ' detroit city; ward 4; precinct 15',
#  'kalamazoo city; 9',
#  'manton city; 1',
#  ' pontiac city; ward 4; precinct 10',
#  'st. clair township; 1',
#  'detroit city; 206',
#  'detroit city; 22',
#  ' utica city; 1',
#  'east tawas city; 1',
#  ' buchanan city; 2',
#  ' tecumseh city; ward 1; precinct 2',
#  ' dearborn city; 47',
#  ' detroit city; ward 4; precinct 45',
#  ' westland city; 7',
#  ' allen park city; 3',
#  'detroit city; 235',
#  'livonia city; 34|c',
#  ' westland city; 38',
#  'lansing city; ward 4; precinct 37',
#  'huntington woods city; 2',
#  'petoskey city; 2',
#  ' detroit city; ward 2; precinct 388',
#  ' detroit city; ward 1; precinct 322',
#  ' detroit city; ward 3; precinct 62',
#  'detroit city; 1059|avcb',
#  ' wayne city; 5',
#  ' pontiac city; ward 7; precinct 19',
#  'dearborn heights city; 22',
#  'sterling heights city; 10',
#  'marshall city; 2',
#  'lansing city; ward 3; precinct 0|23',
#  'detroit city; 1060|avcb',
#  'grand rapids city; ward 3; precinct 71',
#  'lansing city; ward 1; precinct 1',
#  'ypsilanti city; ward 1; precinct 3',
#  ' inkster city; ward 6; precinct 1',
#  ' detroit city; ward 6; precinct 148',
#  ' sturgis city; 1',
#  'charter township of orion; 10',
#  'harper woods city; 6',
#  'detroit city; 1033|avcb',
#  ' burton city; 7',
#  'saginaw city; 14',
#  'kentwood city; ward 2; precinct 12',
#  'detroit city; 998|avcb',
#  ' big rapids city; 1',
#  'jackson city; ward 2; precinct 2',
#  ' flint city; ward 9; precinct 60',
#  'waterford township; 9',
#  'detroit city; 957|avcb',
#  ' rochester hills city; ward 1; precinct 23',
#  'taylor city; 13',
#  'iron river city; 2',
#  'escanaba city; 1',
#  'charter township of bloomfield; 24',
#  ' zeeland city; 1',
#  'melvindale city; 4',
#  'morenci city; 1',
#  'saginaw city; 7',
#  'oak park city; 15',
#  'detroit city; 162',
#  ' grosse pointe park city; 4',
#  'traverse city; 3',
#  ' troy city; 19',
#  ' warren city; ward 1; precinct 46',
#  'white cloud city; 1',
#  ' detroit city; ward 1; precinct 280',
#  ' detroit city; ward 6; precinct 468',
#  'detroit city; 985|avcb',
#  'detroit city; 59',
#  ' detroit city; ward 6; precinct 461',
#  'detroit city; 1002|avcb',
#  'southfield city; 15',
#  ' fenton city; 4',
#  'charter township of orion; 4',
#  'independence township; 8',
#  'south haven city; ward 2; precinct 1',
#  ' port huron city; 10',
#  'battle creek city; 14',
#  ' southfield city; 29',
#  'grand rapids city; ward 1; precinct 15',
#  ' jackson city; ward 3; precinct 3',
#  'detroit city; 258',
#  ' detroit city; ward 4; precinct 26',
#  ' marquette city; 2',
#  ' marlette city; 1',
#  'detroit city; 108',
#  ' taylor city; 26',
#  ' detroit city; ward 7; precinct 346',
#  ' hamtramck city; 1',
#  'rochester hills city; ward 1; precinct 12',
#  'detroit city; 145',
#  ' gibraltar city; 2',
#  'hamtramck city; 7',
#  'dearborn city; 5',
#  'lathrup village city; 1',
#  'south lyon city; 3',
#  ' sault ste marie city; 2',
#  ' troy city; 30',
#  'charter township of commerce; 6',
#  'detroit city; 10',
#  ' alpena city; 1',
#  'kentwood city; ward 2; precinct 15',
#  ' monroe city; 6',
#  ' warren city; ward 1; precinct 19',
#  'detroit city; 1011|avcb',
#  ' lansing city; ward 4; precinct 43',
#  ' ann arbor city; ward 4; precinct 4',
#  ' garden city city; 10',
#  'detroit city; 213',
#  ' alpena city; 6',
#  'charter township of brandon; 1',
#  ' lansing city; ward 3; precinct 25',
#  ' southfield city; 4',
#  ' alma city; 3',
#  ' detroit city; ward 1; precinct 298',
#  ' ann arbor city; ward 4; precinct 3',
#  ' detroit city; ward 4; precinct 17',
#  ' detroit city; ward 6; precinct 472',
#  'monroe city; 2',
#  'detroit city; 217',
#  'flint city; ward 7; precinct 47',
#  ' flushing city; 4',
#  ' st clair shores city; 4',
#  'allen park city; 11',
#  ' hazel park city; 1',
#  'detroit city; 28',
#  'detroit city; 299',
#  'munising city; 1',
#  ' southfield city; 19',
#  'oak park city; 11',
#  'waterford township; 27',
#  'whitewater township; 1',
#  'detroit city; 233',
#  ' novi city; 9',
#  'detroit city; 407',
#  'detroit city; 454',
#  'dewitt township; 1',
#  ' dearborn city; 29',
#  ' springfield city; 2',
#  'southfield township; 6',
#  ' saginaw city; 6',
#  ' troy city; 7',
#  'battle creek city; 19',
#  ' detroit city; ward 1; precinct 308',
#  ' southfield city; 34',
#  'allen park city; 1',
#  ' plymouth city; 1',
#  'holly township; 3',
#  'charter township of waterford; 1',
#  ' benton harbor city; ward 3; precinct 1',
#  ' oak park city; 12',
#  'port huron township; 905|avcb',
#  'mt morris township; 12',
#  'dearborn city; 6',
#  'pontiac city; ward 4; precinct 10',
#  ' flint city; ward 2; precinct 7',
#  ' ann arbor city; ward 3; precinct 8',
#  ' kalamazoo city; 14',
#  'ann arbor city; ward 3; precinct 3',
#  'farmington hills city; 4',
#  'detroit city; 268',
#  'ypsilanti city; ward 1; precinct 2',
#  'grosse pointe park city; 5',
#  ' rochester hills city; ward 1; precinct 26',
#  'farmington hills city; 17',
#  ' detroit city; ward 7; precinct 373',
#  ' livonia city; 35b',
#  'durand city; 2',
#  'mount morris township; 3',
#  'farmington hills city; 10',
#  'detroit city; 95',
#  'davison city; 4',
#  'detroit city; 101',
#  ' midland city; ward 2; precinct 4',
#  ' muskegon city; ward 1; precinct 4',
#  'escanaba city; 2',
#  ' alpena city; 3',
#  ' romulus city; 2',
#  'harper woods city; 4',
#  ' richmond city; 1',
#  'stephenson city; 1',
#  'troy city; 26',
#  'detroit city; 86',
#  ' eastpointe city; 5',
#  'southfield city; 20',
#  ' grand rapids city; ward 2; precinct 46',
#  'detroit city; 1046|avcb',
#  'st. clair shores city; 9',
#  'warren city; ward 3; precinct 32',
#  ' st clair shores city; 16',
#  ' lake city city; 1',
#  'detroit city; 231',
#  'mackinac island city; 1',
#  'zeeland city; 2',
#  'grand rapids city; ward 2; precinct 26',
#  ' ypsilanti city; ward 2; precinct 2',
#  ' flint city; ward 5; precinct 37',
#  'wyoming city; ward 1; precinct 4',
#  ' montrose city; 1',
#  'mount morris township; 9',
#  'saginaw city; 1',
#  'grand rapids city; ward 2; precinct 34',
#  'detroit city; 315',
#  'trenton city; 1',
#  ' detroit city; ward 1; precinct 354',
#  'flint city; ward 9; precinct 58',
#  'detroit city; 945|avcb',
#  ' southgate city; 11',
#  ' stanton city; 1',
#  'fremont city; 1',
#  ' swartz creek city; 2',
#  'detroit city; 982|avcb',
#  ' birmingham city; 9',
#  'battle creek city; 18',
#  ' center line city; 1',
#  ' cheboygan city; 3',
#  'midland city; ward 5; precinct 5',
#  ' detroit city; ward 1; precinct 316',
#  'walled lake city; 2',
#  'highland township; 6',
#  'southfield city; 33',
#  ' albion city; 3',
#  ' allegan city; 2',
#  ' benton harbor city; ward 1; precinct 1',
#  'sturgis city; 2',
#  ' novi city; 15',
#  ' grand haven city; 2',
#  'brandon township; 4',
#  'midland city; ward 4; precinct 5',
#  ' warren city; ward 4; precinct 26',
#  ' sterling heights city; 37',
#  ' detroit city; ward 7; precinct 336',
#  ' detroit city; ward 5; precinct 455',
#  'detroit city; 1052|avcb',
#  'detroit city; 483',
#  ' garden city city; 9',
#  ' wyoming city; ward 1; precinct 8',
#  ' pontiac city; ward 2; precinct 4',
#  ' troy city; 13',
#  'detroit city; 403',
#  ' hamtramck city; 2',
#  'westland city; 40',
#  'oak park city; 1',
#  ' midland city; ward 1; precinct 6',
#  'detroit city; 308',
#  'lansing city; ward 3; precinct 26',
#  'southfield township; 5',
#  'charter township of oxford; 7',
#  ' sterling heights city; 23',
#  'dearborn heights city; 1',
#  'west bloomfield township; 10',
#  'detroit city; 195',
#  'wyoming city; ward 3; precinct 25',
#  ' westland city; 3',
#  'petoskey city; 1',
#  'ironwood city; 1',
#  'rochester hills city; ward 1; precinct 16',
#  'yale city; 1',
#  ' ann arbor city; ward 3; precinct 4',
#  ' muskegon city; ward 3; precinct 8',
#  ' grand rapids city; ward 2; precinct 44',
#  ' trenton city; 2',
#  'east china township; 902|avcb',
#  'novi city; 7',
#  'dewitt township; 5',
#  ' detroit city; ward 2; precinct 215',
#  ' jackson city; ward 2; precinct 1',
#  'clawson city; 1',
#  'charlevoix city; ward 1; precinct 18',
#  ' lowell city; 2',
#  'charter township of west bloomfield; 14',
#  'warren city; ward 1; precinct 19',
#  ' detroit city; ward 4; precinct 24',
#  ' farmington city; ward 1; precinct 5',
#  'hartford city; 1',
#  'harrisville city; ward 1; precinct 1',
#  'detroit city; 913|avcb',
#  ' lansing city; ward 4; precinct 36',
#  ' detroit city; ward 5; precinct 129',
#  'detroit city; 76',
#  'oak park city; 7',
#  ' flint city; ward 6; precinct 39',
#  ' muskegon city; ward 3; precinct 10',
#  ' jackson city; ward 6; precinct 1',
#  ' burton city; 1',
#  'westland city; 1',
#  'grand rapids city; ward 1; precinct 7',
#  ' caro city; 1',
#  'charter township of brandon; 5',
#  'mt morris township; 14',
#  ' ypsilanti city; ward 1; precinct 3',
#  'commerce township; 11',
#  'detroit city; 356',
#  ' midland city; ward 5; precinct 5',
#  ' sturgis city; 2',
#  ' grand rapids city; ward 1; precinct 4',
#  ' pontiac city; ward 2; precinct 5',
#  'detroit city; 270',
#  ' gladstone city; 1',
#  'wyoming city; ward 1; precinct 6',
#  ' lincoln park city; 14',
#  'detroit city; 488',
#  ' highland park city; 18',
#  'westland city; 27',
#  ' wyandotte city; 2',
#  'ann arbor city; ward 1; precinct 7',
#  'charter township of orion; 14',
#  'taylor city; 22',
#  ' dearborn heights city; 1',
#  ' grand rapids city; ward 2; precinct 43',
#  ' muskegon heights city; 3',
#  'lansing city; ward 2; precinct 17',
#  ' ferndale city; 2',
#  'detroit city; 323',
#  ' battle creek city; ward 3; precinct 19',
#  ' marysville city; 3',
#  ' ferndale city; 3',
#  ' grand ledge city; 1',
#  'detroit city; 1005|avcb',
#  'detroit city; 282',
#  ' oak park city; 8',
#  'detroit city; 94',
#  'oakland township; 7',
#  'brandon township; 2',
#  ' detroit city; ward 2; precinct 389',
#  ' southfield city; 20',
#  'lansing city; ward 1; precinct 10',
#  ' flint city; ward 2; precinct 13',
#  'clay township; 903|avcb',
#  'mount morris township; 1',
#  'southfield township; 2',
#  ' dearborn city; 22',
#  'south haven city; ward 3; precinct 1',
#  ' adrian city; 2',
#  'cheboygan city; 3',
#  'detroit city; 423',
#  ' troy city; 25',
#  'westland city; 14',
#  ' kentwood city; ward 1; precinct 1',
#  ' wyoming city; ward 1; precinct 9',
#  ' detroit city; ward 7; precinct 390',
#  'center line city; 3',
#  'waterford township; 20',
#  'detroit city; 936|avcb',
#  'west bloomfield township; 24',
#  'bloomfield township; 29',
#  ' detroit city; ward 1; precinct 261',
#  'highland park city; 12',
#  'detroit city; 974|avcb',
#  'lansing city; ward 3; precinct 31',
#  'riverview city; 1',
#  ' rose city city; ward 1; precinct 1',
#  ' allen park city; 4',
#  'detroit city; 392',
#  ' detroit city; ward 4; precinct 8',
#  'newaygo city; 1',
#  'battle creek city; 17',
#  ' ypsilanti city; ward 3; precinct 2',
#  ' new baltimore city; 2',
#  'berkley city; 7',
#  'jackson city; ward 3; precinct 3',
#  ' kentwood city; ward 2; precinct 14',
#  ' alpena city; 4',
#  'bloomfield township; 24',
#  'orchard lake village city; 1',
#  'st. johns city; 2',
#  'grand rapids city; ward 3; precinct 56',
#  'detroit city; 1007|avcb',
#  ' st clair shores city; 2',
#  ' onaway city; 1',
#  ' grand rapids city; ward 3; precinct 57',
#  'benton harbor city; 1',
#  'grand rapids city; ward 3; precinct 75',
#  ' romulus city; 9',
#  'west branch city; ward 1; precinct 1',
#  'wyoming city; ward 1; precinct 1',
#  ' south haven city; ward 3; precinct 2',
#  'detroit city; 1019|avcb',
#  'warren city; ward 3; precinct 24',
#  'charter township of independence; 10',
#  'clawson city; 3',
#  'detroit city; 69',
#  ' novi city; 5',
#  'saginaw city; 9',
#  'charter township of bloomfield; 31',
#  ' detroit city; ward 5; precinct 436',
#  ' detroit city; ward 2; precinct 382',
#  ' fenton city; 3',
#  ' roseville city; 11',
#  'detroit city; 186',
#  'dearborn city; 44',
#  'charter township of white lake; 10',
#  ' detroit city; ward 2; precinct 248',
#  'charter township of lyon; 3',
#  'madison heights city; 11',
#  'pontiac city; ward 1; precinct 2',
#  ' midland city; ward 3; precinct 1',
#  ' lansing city; ward 4; precinct 39',
#  'detroit city; 1025|avcb',
#  'detroit city; 432',
#  ' flint city; ward 4; precinct 27',
#  'white water township; 1',
#  ' sterling heights city; 16',
#  'detroit city; 144',
#  ' ann arbor city; ward 3; precinct 9',
#  ' birmingham city; 2',
#  'westland city; 2',
#  ' crystal falls city; 1',
#  'southfield city; 2',
#  'highland park city; 20',
#  ' detroit city; ward 3; precinct 73',
#  ' detroit city; ward 1; precinct 273',
#  ' grand rapids city; ward 3; precinct 63',
#  ' kalamazoo city; 15',
#  ' detroit city; ward 6; precinct 470',
#  'ecorse city; 3',
#  'niles city; 4',
#  ' ann arbor city; ward 3; precinct 5',
#  ' lansing city; ward 1; precinct 2',
#  ' novi city; 14',
#  'detroit city; 88',
#  'rochester hills city; ward 1; precinct 27',
#  ' grand haven city; 3',
#  ' grosse pointe woods city; 1',
#  'southgate city; 2',
#  'wyoming city; ward 2; precinct 11',
#  'davison city; 1',
#  'jackson city; ward 4; precinct 2',
#  'oxford township; 7',
#  ' grand rapids city; ward 1; precinct 22',
#  'allen park city; 13',
#  ' warren city; ward 5; precinct 9',
#  'algonac city; 1',
#  ' iron mountain city; ward 2; precinct 2',
#  'charter township of bloomfield; 9',
#  'bessemer city; 1',
#  'livonia city; 35|a',
#  ' dearborn heights city; 26',
#  'dearborn city; 19',
#  'charter township of oakland; 3',
#  'grand rapids city; ward 2; precinct 28',
#  'st. clair city; 3',
#  'adrian city; 4',
#  'milford township; 5',
#  ' monroe city; 4',
#  ' bay city city; ward 2; precinct 1',
#  'ferndale city; 8',
#  ' grand rapids city; ward 3; precinct 59',
#  ' muskegon city; ward 2; precinct 6',
#  ' pontiac city; ward 1; precinct 3',
#  'kalamazoo city; 12',
#  'charter township of white lake; 12',
#  'birmingham city; 3',
#  'detroit city; 8',
#  ' detroit city; ward 6; precinct 147',
#  'detroit city; 1051|avcb',
#  'lansing city; ward 4; precinct 36',
#  ' east grand rapids city; ward 1; precinct 1',
#  ' marysville city; 1',
#  ' oak park city; 7',
#  'west bloomfield township; 13',
#  'detroit city; 438',
#  ' grosse pointe farms city; 1',
#  'walker city; ward 2; precinct 4',
#  'grand haven city; 4',
#  ' sterling heights city; 24',
#  ' trenton city; 7',
#  ' southfield city; 3',
#  ' detroit city; ward 2; precinct 259',
#  ' detroit city; ward 6; precinct 151',
#  ' dearborn city; 8',
#  'caro city; 1',
#  ' grand rapids city; ward 1; precinct 20',
#  'detroit city; 155',
#  ' detroit city; ward 5; precinct 434',
#  'jackson city; ward 6; precinct 3',
#  'albion city; 2',
#  ' hastings city; 4',
#  ' st clair shores city; 20',
#  'southfield city; 10',
#  'grand rapids city; ward 1; precinct 12',
#  'detroit city; 480',
#  ' detroit city; ward 3; precinct 63',
#  'livonia city; 4|a',
#  'detroit city; 264',
#  'burton city; 9',
#  'pontiac city; ward 1; precinct 1',
#  ' rochester hills city; ward 3; precinct 12',
#  'detroit city; 973|avcb',
#  'livonia city; 8|b',
#  'detroit city; 369',
#  'fraser city; 6',
#  'charter township of commerce; 1',
#  'roseville city; 11',
#  ' east grand rapids city; ward 3; precinct 6',
#  'waterford township; 10',
#  'holland city; ward 3; precinct 7',
#  'detroit city; 286',
#  'woodhaven city; 5',
#  ' ann arbor city; ward 3; precinct 1',
#  ' warren city; ward 5; precinct 8',
#  'ann arbor city; ward 1; precinct 4',
#  'grosse pointe city; 2',
#  'jackson city; ward 3; precinct 1',
#  'walker city; ward 3; precinct 8',
#  ' burton city; 8',
#  ' monroe city; 3s',
#  'manistique city; 3',
#  'sterling heights city; 15',
#  ' norton shores city; ward 1; precinct 2',
#  'farmington hills city; 24',
#  ' cadillac city; 3',
#  'waterford township; 28',
#  'charlotte city; ward 1; precinct 1',
#  ' fraser city; 7',
#  ' detroit city; ward 6; precinct 421',
#  'eastpointe city; 7',
#  ' hillsdale city; ward 1; precinct 1',
#  ' hamtramck city; 4',
#  'jackson city; ward 4; precinct 3',
#  'flint city; ward 8; precinct 52',
#  ' royal oak city; 5',
#  ' allen park city; 14',
#  'detroit city; 1044|avcb',
#  ' st johns city; 1',
#  'grosse pointe park city; 1',
#  'detroit city; 191',
#  ' detroit city; ward 1; precinct 490',
#  'kalamazoo city; 27',
#  'ann arbor city; ward 4; precinct 4',
#  'charter township of bloomfield; 25',
#  'warren city; ward 1; precinct 34',
#  ' detroit city; ward 2; precinct 381',
#  'detroit city; 938|avcb',
#  ' st clair shores city; 21',
#  ' sterling heights city; 10',
#  ' detroit city; ward 6; precinct 451',
#  ' monroe city; 2',
#  'charter township of orion; 2',
#  'detroit city; 435',
#  ' detroit city; ward 4; precinct 55',
#  ' lansing city; ward 2; precinct 18',
#  ' st clair shores city; 6',
#  'charter township of independence; 11',
#  'westland city; 11',
#  ' ishpeming city; 2',
#  'novi city; 11',
#  ' algonac city; 1',
#  'detroit city; 240',
#  ' mt clemens city; 1',
#  'kalamazoo city; 17',
#  ' bay city city; ward 5; precinct 1',
#  ' flint city; ward 7; precinct 49',
#  ' detroit city; ward 3; precinct 90',
#  ' lansing city; ward 1; precinct 3',
#  'detroit city; 1041|avcb',
#  ' farmington hills city; 24',
#  'rochester hills city; ward 1; precinct 24',
#  ' holland city; ward 3; precinct 6',
#  'midland city; ward 3; precinct 4',
#  ' detroit city; ward 3; precinct 70',
#  'sterling heights city; 3',
#  ' norton shores city; ward 2; precinct 7',
#  'madison heights city; 7',
#  ' detroit city; ward 7; precinct 412',
#  ' detroit city; ward 1; precinct 320',
#  'waterford township; 14',
#  ' taylor city; 14',
#  ' kalamazoo city; 26',
#  'wyoming city; ward 3; precinct 27',
#  'kentwood city; ward 1; precinct 5',
#  ' farmington hills city; 20',
#  'detroit city; 140',
#  'troy city; 29',
#  ' caspian city; 1',
#  'harrison city; 1',
#  'howell city; 2',
#  'allen park city; 4',
#  'imlay city; 2',
#  'novi city; 14',
#  ' detroit city; ward 3; precinct 67',
#  'wixom city; 2',
#  'fenton city; 2',
#  ' port huron city; 2',
#  'detroit city; 916|avcb',
#  ' st clair shores city; 9',
#  'bloomfield township; 31',
#  ' wyoming city; ward 1; precinct 4',
#  'burton city; 12',
#  'warren city; ward 2; precinct 37',
#  ' wyoming city; ward 1; precinct 7',
#  'lansing city; ward 1; precinct 8',
#  'detroit city; 905|avcb',
#  ' detroit city; ward 7; precinct 404',
#  'kalamazoo city; 26',
#  'detroit city; 381',
#  'midland city; ward 1; precinct 4',
#  'flint city; ward 2; precinct 12',
#  'dearborn city; 1',
#  'detroit city; 276',
#  ' warren city; ward 2; precinct 43',
#  ' detroit city; ward 1; precinct 315',
#  'detroit city; 990|avcb',
#  'houghton city; 2',
#  'detroit city; 123',
#  ' ann arbor city; ward 5; precinct 5',
#  'flint city; ward 3; precinct 15',
#  ' detroit city; ward 2; precinct 237',
#  'livonia city; 2|a',
#  ' wyoming city; ward 3; precinct 26',
#  'taylor city; 27',
#  ' wyoming city; ward 2; precinct 12',
#  ' south lyon city; 1',
#  'negaunee city; 1',
#  'silver creek township; 901|avcb',
#  'mount pleasant city; 3',
#  ' troy city; 9',
#  'detroit city; 238',
#  'novi city; 20',
#  ' wyandotte city; 4',
#  ' ypsilanti city; ward 3; precinct 1',
#  'west bloomfield township; 2',
#  'taylor city; 18',
#  'lansing city; ward 4; precinct 40',
#  'charter township of highland; 5',
#  'highland township; 8',
#  'mt morris township; 6',
#  ' ann arbor city; ward 2; precinct 3',
#  ' eastpointe city; 8',
#  'charter township of independence; 2',
#  ' detroit city; ward 4; precinct 76',
#  ' pontiac city; ward 5; precinct 15',
#  ' jackson city; ward 6; precinct 2',
#  'warren city; ward 4; precinct 30',
#  'pleasant ridge city; 1',
#  ' detroit city; ward 2; precinct 258',
#  'lansing city; ward 3; precinct 25',
#  'detroit city; 375',
#  ' dearborn city; 4',
#  'detroit city; 205',
#  'coldwater city; ward 3; precinct 1',
#  'lansing city; ward 3; precinct 24',
#  'detroit city; 969|avcb',
#  ' kalamazoo city; 5',
#  ' detroit city; ward 5; precinct 99',
#  ' dearborn city; 30',
#  'ann arbor city; ward 5; precinct 6',
#  ' port huron city; 8',
#  'portage city; 14',
#  ' detroit city; ward 1; precinct 254',
#  ' lansing city; ward 1; precinct 5',
#  ' detroit city; ward 5; precinct 132',
#  ' livonia city; 31a',
#  'lansing city; ward 4; precinct 35',
#  'lansing city; ward 2; precinct 20',
#  ' westland city; 20',
#  'livonia city; 33|a',
#  'troy city; 15',
#  'pontiac city; ward 6; precinct 18',
#  'flint city; ward 3; precinct 19',
#  'st. clair shores city; 10',
#  'detroit city; 29',
#  'grand rapids city; ward 3; precinct 58',
#  ' battle creek city; ward 4; precinct 9',
#  'inkster city; ward 4; precinct 1',
#  'detroit city; 100',
#  ' detroit city; ward 6; precinct 460',
#  'detroit city; 460',
#  ' detroit city; ward 2; precinct 290',
#  ' detroit city; ward 5; precinct 442',
#  ' detroit city; ward 1; precinct 358',
#  ' flint city; ward 8; precinct 53',
#  'charter township of commerce; 3',
#  ' midland city; ward 1; precinct 1',
#  ' harper woods city; 2',
#  'taylor city; 10',
#  ' detroit city; ward 3; precinct 174',
#  ' grand rapids city; ward 1; precinct 12',
#  'detroit city; 199',
#  'mount clemens city; 3',
#  'detroit city; 174',
#  'detroit city; 3',
#  'st. johns city; 1',
#  ' detroit city; ward 7; precinct 372',
#  'burton city; 5',
#  'big rapids city; 1',
#  ' royal oak city; 17',
#  'sault ste. marie city; 3',
#  'grand rapids city; ward 2; precinct 50',
#  ' rochester hills city; ward 2; precinct 21',
#  'detroit city; 337',
#  ' albion city; 2',
#  'flint city; ward 5; precinct 38',
#  ' battle creek city; ward 4; precinct 2',
#  ' detroit city; ward 7; precinct 363',
#  'roseville city; 13',
#  'adrian city; 2',
#  'detroit city; 1037|avcb',
#  ' st clair city; 3',
#  ' detroit city; ward 1; precinct 303',
#  'wyoming city; ward 3; precinct 23',
#  'wyoming city; ward 3; precinct 21',
#  'burton city; 6',
#  ' dearborn city; 17',
#  'muskegon city; ward 1; precinct 3',
#  'charter township of oxford; 3',
#  'dearborn city; 35',
#  'wyandotte city; 1',
#  ' detroit city; ward 4; precinct 59',
#  ' detroit city; ward 1; precinct 262',
#  'ann arbor city; ward 5; precinct 5',
#  'detroit city; 20',
#  'madison heights city; 6',
#  ' grand rapids city; ward 2; precinct 31',
#  ' greenville city; 2',
#  'kentwood city; ward 1; precinct 1',
#  'howell city; 1',
#  ' detroit city; ward 5; precinct 152',
#  'kalamazoo city; 6',
#  ...}

# %%
from reference_data import geoid_to_county_name
geoid_to_county_name
# Out:
# {'01001': 'Autauga County',
#  '01003': 'Baldwin County',
#  '01005': 'Barbour County',
#  '01007': 'Bibb County',
#  '01009': 'Blount County',
#  '01011': 'Bullock County',
#  '01013': 'Butler County',
#  '01015': 'Calhoun County',
#  '01017': 'Chambers County',
#  '01019': 'Cherokee County',
#  '01021': 'Chilton County',
#  '01023': 'Choctaw County',
#  '01025': 'Clarke County',
#  '01027': 'Clay County',
#  '01029': 'Cleburne County',
#  '01031': 'Coffee County',
#  '01033': 'Colbert County',
#  '01035': 'Conecuh County',
#  '01037': 'Coosa County',
#  '01039': 'Covington County',
#  '01041': 'Crenshaw County',
#  '01043': 'Cullman County',
#  '01045': 'Dale County',
#  '01047': 'Dallas County',
#  '01049': 'DeKalb County',
#  '01051': 'Elmore County',
#  '01053': 'Escambia County',
#  '01055': 'Etowah County',
#  '01057': 'Fayette County',
#  '01059': 'Franklin County',
#  '01061': 'Geneva County',
#  '01063': 'Greene County',
#  '01065': 'Hale County',
#  '01067': 'Henry County',
#  '01069': 'Houston County',
#  '01071': 'Jackson County',
#  '01073': 'Jefferson County',
#  '01075': 'Lamar County',
#  '01077': 'Lauderdale County',
#  '01079': 'Lawrence County',
#  '01081': 'Lee County',
#  '01083': 'Limestone County',
#  '01085': 'Lowndes County',
#  '01087': 'Macon County',
#  '01089': 'Madison County',
#  '01091': 'Marengo County',
#  '01093': 'Marion County',
#  '01095': 'Marshall County',
#  '01097': 'Mobile County',
#  '01099': 'Monroe County',
#  '01101': 'Montgomery County',
#  '01103': 'Morgan County',
#  '01105': 'Perry County',
#  '01107': 'Pickens County',
#  '01109': 'Pike County',
#  '01111': 'Randolph County',
#  '01113': 'Russell County',
#  '01115': 'St. Clair County',
#  '01117': 'Shelby County',
#  '01119': 'Sumter County',
#  '01121': 'Talladega County',
#  '01123': 'Tallapoosa County',
#  '01125': 'Tuscaloosa County',
#  '01127': 'Walker County',
#  '01129': 'Washington County',
#  '01131': 'Wilcox County',
#  '01133': 'Winston County',
#  '02013': 'Aleutians East Borough',
#  '02016': 'Aleutians West Census Area',
#  '02020': 'Anchorage Municipality',
#  '02050': 'Bethel Census Area',
#  '02060': 'Bristol Bay Borough',
#  '02068': 'Denali Borough',
#  '02070': 'Dillingham Census Area',
#  '02090': 'Fairbanks North Star Borough',
#  '02100': 'Haines Borough',
#  '02105': 'Hoonah-Angoon Census Area',
#  '02110': 'Juneau City and Borough',
#  '02122': 'Kenai Peninsula Borough',
#  '02130': 'Ketchikan Gateway Borough',
#  '02150': 'Kodiak Island Borough',
#  '02158': 'Kusilvak Census Area',
#  '02164': 'Lake and Peninsula Borough',
#  '02170': 'Matanuska-Susitna Borough',
#  '02180': 'Nome Census Area',
#  '02185': 'North Slope Borough',
#  '02188': 'Northwest Arctic Borough',
#  '02195': 'Petersburg Borough',
#  '02198': 'Prince of Wales-Hyder Census Area',
#  '02220': 'Sitka City and Borough',
#  '02230': 'Skagway Municipality',
#  '02240': 'Southeast Fairbanks Census Area',
#  '02261': 'Valdez-Cordova Census Area',
#  '02275': 'Wrangell City and Borough',
#  '02282': 'Yakutat City and Borough',
#  '02290': 'Yukon-Koyukuk Census Area',
#  '04001': 'Apache County',
#  '04003': 'Cochise County',
#  '04005': 'Coconino County',
#  '04007': 'Gila County',
#  '04009': 'Graham County',
#  '04011': 'Greenlee County',
#  '04012': 'La Paz County',
#  '04013': 'Maricopa County',
#  '04015': 'Mohave County',
#  '04017': 'Navajo County',
#  '04019': 'Pima County',
#  '04021': 'Pinal County',
#  '04023': 'Santa Cruz County',
#  '04025': 'Yavapai County',
#  '04027': 'Yuma County',
#  '05001': 'Arkansas County',
#  '05003': 'Ashley County',
#  '05005': 'Baxter County',
#  '05007': 'Benton County',
#  '05009': 'Boone County',
#  '05011': 'Bradley County',
#  '05013': 'Calhoun County',
#  '05015': 'Carroll County',
#  '05017': 'Chicot County',
#  '05019': 'Clark County',
#  '05021': 'Clay County',
#  '05023': 'Cleburne County',
#  '05025': 'Cleveland County',
#  '05027': 'Columbia County',
#  '05029': 'Conway County',
#  '05031': 'Craighead County',
#  '05033': 'Crawford County',
#  '05035': 'Crittenden County',
#  '05037': 'Cross County',
#  '05039': 'Dallas County',
#  '05041': 'Desha County',
#  '05043': 'Drew County',
#  '05045': 'Faulkner County',
#  '05047': 'Franklin County',
#  '05049': 'Fulton County',
#  '05051': 'Garland County',
#  '05053': 'Grant County',
#  '05055': 'Greene County',
#  '05057': 'Hempstead County',
#  '05059': 'Hot Spring County',
#  '05061': 'Howard County',
#  '05063': 'Independence County',
#  '05065': 'Izard County',
#  '05067': 'Jackson County',
#  '05069': 'Jefferson County',
#  '05071': 'Johnson County',
#  '05073': 'Lafayette County',
#  '05075': 'Lawrence County',
#  '05077': 'Lee County',
#  '05079': 'Lincoln County',
#  '05081': 'Little River County',
#  '05083': 'Logan County',
#  '05085': 'Lonoke County',
#  '05087': 'Madison County',
#  '05089': 'Marion County',
#  '05091': 'Miller County',
#  '05093': 'Mississippi County',
#  '05095': 'Monroe County',
#  '05097': 'Montgomery County',
#  '05099': 'Nevada County',
#  '05101': 'Newton County',
#  '05103': 'Ouachita County',
#  '05105': 'Perry County',
#  '05107': 'Phillips County',
#  '05109': 'Pike County',
#  '05111': 'Poinsett County',
#  '05113': 'Polk County',
#  '05115': 'Pope County',
#  '05117': 'Prairie County',
#  '05119': 'Pulaski County',
#  '05121': 'Randolph County',
#  '05123': 'St. Francis County',
#  '05125': 'Saline County',
#  '05127': 'Scott County',
#  '05129': 'Searcy County',
#  '05131': 'Sebastian County',
#  '05133': 'Sevier County',
#  '05135': 'Sharp County',
#  '05137': 'Stone County',
#  '05139': 'Union County',
#  '05141': 'Van Buren County',
#  '05143': 'Washington County',
#  '05145': 'White County',
#  '05147': 'Woodruff County',
#  '05149': 'Yell County',
#  '06001': 'Alameda County',
#  '06003': 'Alpine County',
#  '06005': 'Amador County',
#  '06007': 'Butte County',
#  '06009': 'Calaveras County',
#  '06011': 'Colusa County',
#  '06013': 'Contra Costa County',
#  '06015': 'Del Norte County',
#  '06017': 'El Dorado County',
#  '06019': 'Fresno County',
#  '06021': 'Glenn County',
#  '06023': 'Humboldt County',
#  '06025': 'Imperial County',
#  '06027': 'Inyo County',
#  '06029': 'Kern County',
#  '06031': 'Kings County',
#  '06033': 'Lake County',
#  '06035': 'Lassen County',
#  '06037': 'Los Angeles County',
#  '06039': 'Madera County',
#  '06041': 'Marin County',
#  '06043': 'Mariposa County',
#  '06045': 'Mendocino County',
#  '06047': 'Merced County',
#  '06049': 'Modoc County',
#  '06051': 'Mono County',
#  '06053': 'Monterey County',
#  '06055': 'Napa County',
#  '06057': 'Nevada County',
#  '06059': 'Orange County',
#  '06061': 'Placer County',
#  '06063': 'Plumas County',
#  '06065': 'Riverside County',
#  '06067': 'Sacramento County',
#  '06069': 'San Benito County',
#  '06071': 'San Bernardino County',
#  '06073': 'San Diego County',
#  '06075': 'San Francisco County',
#  '06077': 'San Joaquin County',
#  '06079': 'San Luis Obispo County',
#  '06081': 'San Mateo County',
#  '06083': 'Santa Barbara County',
#  '06085': 'Santa Clara County',
#  '06087': 'Santa Cruz County',
#  '06089': 'Shasta County',
#  '06091': 'Sierra County',
#  '06093': 'Siskiyou County',
#  '06095': 'Solano County',
#  '06097': 'Sonoma County',
#  '06099': 'Stanislaus County',
#  '06101': 'Sutter County',
#  '06103': 'Tehama County',
#  '06105': 'Trinity County',
#  '06107': 'Tulare County',
#  '06109': 'Tuolumne County',
#  '06111': 'Ventura County',
#  '06113': 'Yolo County',
#  '06115': 'Yuba County',
#  '08001': 'Adams County',
#  '08003': 'Alamosa County',
#  '08005': 'Arapahoe County',
#  '08007': 'Archuleta County',
#  '08009': 'Baca County',
#  '08011': 'Bent County',
#  '08013': 'Boulder County',
#  '08014': 'Broomfield County',
#  '08015': 'Chaffee County',
#  '08017': 'Cheyenne County',
#  '08019': 'Clear Creek County',
#  '08021': 'Conejos County',
#  '08023': 'Costilla County',
#  '08025': 'Crowley County',
#  '08027': 'Custer County',
#  '08029': 'Delta County',
#  '08031': 'Denver County',
#  '08033': 'Dolores County',
#  '08035': 'Douglas County',
#  '08037': 'Eagle County',
#  '08039': 'Elbert County',
#  '08041': 'El Paso County',
#  '08043': 'Fremont County',
#  '08045': 'Garfield County',
#  '08047': 'Gilpin County',
#  '08049': 'Grand County',
#  '08051': 'Gunnison County',
#  '08053': 'Hinsdale County',
#  '08055': 'Huerfano County',
#  '08057': 'Jackson County',
#  '08059': 'Jefferson County',
#  '08061': 'Kiowa County',
#  '08063': 'Kit Carson County',
#  '08065': 'Lake County',
#  '08067': 'La Plata County',
#  '08069': 'Larimer County',
#  '08071': 'Las Animas County',
#  '08073': 'Lincoln County',
#  '08075': 'Logan County',
#  '08077': 'Mesa County',
#  '08079': 'Mineral County',
#  '08081': 'Moffat County',
#  '08083': 'Montezuma County',
#  '08085': 'Montrose County',
#  '08087': 'Morgan County',
#  '08089': 'Otero County',
#  '08091': 'Ouray County',
#  '08093': 'Park County',
#  '08095': 'Phillips County',
#  '08097': 'Pitkin County',
#  '08099': 'Prowers County',
#  '08101': 'Pueblo County',
#  '08103': 'Rio Blanco County',
#  '08105': 'Rio Grande County',
#  '08107': 'Routt County',
#  '08109': 'Saguache County',
#  '08111': 'San Juan County',
#  '08113': 'San Miguel County',
#  '08115': 'Sedgwick County',
#  '08117': 'Summit County',
#  '08119': 'Teller County',
#  '08121': 'Washington County',
#  '08123': 'Weld County',
#  '08125': 'Yuma County',
#  '09001': 'Fairfield County',
#  '09003': 'Hartford County',
#  '09005': 'Litchfield County',
#  '09007': 'Middlesex County',
#  '09009': 'New Haven County',
#  '09011': 'New London County',
#  '09013': 'Tolland County',
#  '09015': 'Windham County',
#  '10001': 'Kent County',
#  '10003': 'New Castle County',
#  '10005': 'Sussex County',
#  '11001': 'District of Columbia',
#  '12001': 'Alachua County',
#  '12003': 'Baker County',
#  '12005': 'Bay County',
#  '12007': 'Bradford County',
#  '12009': 'Brevard County',
#  '12011': 'Broward County',
#  '12013': 'Calhoun County',
#  '12015': 'Charlotte County',
#  '12017': 'Citrus County',
#  '12019': 'Clay County',
#  '12021': 'Collier County',
#  '12023': 'Columbia County',
#  '12027': 'DeSoto County',
#  '12029': 'Dixie County',
#  '12031': 'Duval County',
#  '12033': 'Escambia County',
#  '12035': 'Flagler County',
#  '12037': 'Franklin County',
#  '12039': 'Gadsden County',
#  '12041': 'Gilchrist County',
#  '12043': 'Glades County',
#  '12045': 'Gulf County',
#  '12047': 'Hamilton County',
#  '12049': 'Hardee County',
#  '12051': 'Hendry County',
#  '12053': 'Hernando County',
#  '12055': 'Highlands County',
#  '12057': 'Hillsborough County',
#  '12059': 'Holmes County',
#  '12061': 'Indian River County',
#  '12063': 'Jackson County',
#  '12065': 'Jefferson County',
#  '12067': 'Lafayette County',
#  '12069': 'Lake County',
#  '12071': 'Lee County',
#  '12073': 'Leon County',
#  '12075': 'Levy County',
#  '12077': 'Liberty County',
#  '12079': 'Madison County',
#  '12081': 'Manatee County',
#  '12083': 'Marion County',
#  '12085': 'Martin County',
#  '12086': 'Miami-Dade County',
#  '12087': 'Monroe County',
#  '12089': 'Nassau County',
#  '12091': 'Okaloosa County',
#  '12093': 'Okeechobee County',
#  '12095': 'Orange County',
#  '12097': 'Osceola County',
#  '12099': 'Palm Beach County',
#  '12101': 'Pasco County',
#  '12103': 'Pinellas County',
#  '12105': 'Polk County',
#  '12107': 'Putnam County',
#  '12109': 'St. Johns County',
#  '12111': 'St. Lucie County',
#  '12113': 'Santa Rosa County',
#  '12115': 'Sarasota County',
#  '12117': 'Seminole County',
#  '12119': 'Sumter County',
#  '12121': 'Suwannee County',
#  '12123': 'Taylor County',
#  '12125': 'Union County',
#  '12127': 'Volusia County',
#  '12129': 'Wakulla County',
#  '12131': 'Walton County',
#  '12133': 'Washington County',
#  '13001': 'Appling County',
#  '13003': 'Atkinson County',
#  '13005': 'Bacon County',
#  '13007': 'Baker County',
#  '13009': 'Baldwin County',
#  '13011': 'Banks County',
#  '13013': 'Barrow County',
#  '13015': 'Bartow County',
#  '13017': 'Ben Hill County',
#  '13019': 'Berrien County',
#  '13021': 'Bibb County',
#  '13023': 'Bleckley County',
#  '13025': 'Brantley County',
#  '13027': 'Brooks County',
#  '13029': 'Bryan County',
#  '13031': 'Bulloch County',
#  '13033': 'Burke County',
#  '13035': 'Butts County',
#  '13037': 'Calhoun County',
#  '13039': 'Camden County',
#  '13043': 'Candler County',
#  '13045': 'Carroll County',
#  '13047': 'Catoosa County',
#  '13049': 'Charlton County',
#  '13051': 'Chatham County',
#  '13053': 'Chattahoochee County',
#  '13055': 'Chattooga County',
#  '13057': 'Cherokee County',
#  '13059': 'Clarke County',
#  '13061': 'Clay County',
#  '13063': 'Clayton County',
#  '13065': 'Clinch County',
#  '13067': 'Cobb County',
#  '13069': 'Coffee County',
#  '13071': 'Colquitt County',
#  '13073': 'Columbia County',
#  '13075': 'Cook County',
#  '13077': 'Coweta County',
#  '13079': 'Crawford County',
#  '13081': 'Crisp County',
#  '13083': 'Dade County',
#  '13085': 'Dawson County',
#  '13087': 'Decatur County',
#  '13089': 'DeKalb County',
#  '13091': 'Dodge County',
#  '13093': 'Dooly County',
#  '13095': 'Dougherty County',
#  '13097': 'Douglas County',
#  '13099': 'Early County',
#  '13101': 'Echols County',
#  '13103': 'Effingham County',
#  '13105': 'Elbert County',
#  '13107': 'Emanuel County',
#  '13109': 'Evans County',
#  '13111': 'Fannin County',
#  '13113': 'Fayette County',
#  '13115': 'Floyd County',
#  '13117': 'Forsyth County',
#  '13119': 'Franklin County',
#  '13121': 'Fulton County',
#  '13123': 'Gilmer County',
#  '13125': 'Glascock County',
#  '13127': 'Glynn County',
#  '13129': 'Gordon County',
#  '13131': 'Grady County',
#  '13133': 'Greene County',
#  '13135': 'Gwinnett County',
#  '13137': 'Habersham County',
#  '13139': 'Hall County',
#  '13141': 'Hancock County',
#  '13143': 'Haralson County',
#  '13145': 'Harris County',
#  '13147': 'Hart County',
#  '13149': 'Heard County',
#  '13151': 'Henry County',
#  '13153': 'Houston County',
#  '13155': 'Irwin County',
#  '13157': 'Jackson County',
#  '13159': 'Jasper County',
#  '13161': 'Jeff Davis County',
#  '13163': 'Jefferson County',
#  '13165': 'Jenkins County',
#  '13167': 'Johnson County',
#  '13169': 'Jones County',
#  '13171': 'Lamar County',
#  '13173': 'Lanier County',
#  '13175': 'Laurens County',
#  '13177': 'Lee County',
#  '13179': 'Liberty County',
#  '13181': 'Lincoln County',
#  '13183': 'Long County',
#  '13185': 'Lowndes County',
#  '13187': 'Lumpkin County',
#  '13189': 'McDuffie County',
#  '13191': 'McIntosh County',
#  '13193': 'Macon County',
#  '13195': 'Madison County',
#  '13197': 'Marion County',
#  '13199': 'Meriwether County',
#  '13201': 'Miller County',
#  '13205': 'Mitchell County',
#  '13207': 'Monroe County',
#  '13209': 'Montgomery County',
#  '13211': 'Morgan County',
#  '13213': 'Murray County',
#  '13215': 'Muscogee County',
#  '13217': 'Newton County',
#  '13219': 'Oconee County',
#  '13221': 'Oglethorpe County',
#  '13223': 'Paulding County',
#  '13225': 'Peach County',
#  '13227': 'Pickens County',
#  '13229': 'Pierce County',
#  '13231': 'Pike County',
#  '13233': 'Polk County',
#  '13235': 'Pulaski County',
#  '13237': 'Putnam County',
#  '13239': 'Quitman County',
#  '13241': 'Rabun County',
#  '13243': 'Randolph County',
#  '13245': 'Richmond County',
#  '13247': 'Rockdale County',
#  '13249': 'Schley County',
#  '13251': 'Screven County',
#  '13253': 'Seminole County',
#  '13255': 'Spalding County',
#  '13257': 'Stephens County',
#  '13259': 'Stewart County',
#  '13261': 'Sumter County',
#  '13263': 'Talbot County',
#  '13265': 'Taliaferro County',
#  '13267': 'Tattnall County',
#  '13269': 'Taylor County',
#  '13271': 'Telfair County',
#  '13273': 'Terrell County',
#  '13275': 'Thomas County',
#  '13277': 'Tift County',
#  '13279': 'Toombs County',
#  '13281': 'Towns County',
#  '13283': 'Treutlen County',
#  '13285': 'Troup County',
#  '13287': 'Turner County',
#  '13289': 'Twiggs County',
#  '13291': 'Union County',
#  '13293': 'Upson County',
#  '13295': 'Walker County',
#  '13297': 'Walton County',
#  '13299': 'Ware County',
#  '13301': 'Warren County',
#  '13303': 'Washington County',
#  '13305': 'Wayne County',
#  '13307': 'Webster County',
#  '13309': 'Wheeler County',
#  '13311': 'White County',
#  '13313': 'Whitfield County',
#  '13315': 'Wilcox County',
#  '13317': 'Wilkes County',
#  '13319': 'Wilkinson County',
#  '13321': 'Worth County',
#  '15001': 'Hawaii County',
#  '15003': 'Honolulu County',
#  '15005': 'Kalawao County',
#  '15007': 'Kauai County',
#  '15009': 'Maui County',
#  '16001': 'Ada County',
#  '16003': 'Adams County',
#  '16005': 'Bannock County',
#  '16007': 'Bear Lake County',
#  '16009': 'Benewah County',
#  '16011': 'Bingham County',
#  '16013': 'Blaine County',
#  '16015': 'Boise County',
#  '16017': 'Bonner County',
#  '16019': 'Bonneville County',
#  '16021': 'Boundary County',
#  '16023': 'Butte County',
#  '16025': 'Camas County',
#  '16027': 'Canyon County',
#  '16029': 'Caribou County',
#  '16031': 'Cassia County',
#  '16033': 'Clark County',
#  '16035': 'Clearwater County',
#  '16037': 'Custer County',
#  '16039': 'Elmore County',
#  '16041': 'Franklin County',
#  '16043': 'Fremont County',
#  '16045': 'Gem County',
#  '16047': 'Gooding County',
#  '16049': 'Idaho County',
#  '16051': 'Jefferson County',
#  '16053': 'Jerome County',
#  '16055': 'Kootenai County',
#  '16057': 'Latah County',
#  '16059': 'Lemhi County',
#  '16061': 'Lewis County',
#  '16063': 'Lincoln County',
#  '16065': 'Madison County',
#  '16067': 'Minidoka County',
#  '16069': 'Nez Perce County',
#  '16071': 'Oneida County',
#  '16073': 'Owyhee County',
#  '16075': 'Payette County',
#  '16077': 'Power County',
#  '16079': 'Shoshone County',
#  '16081': 'Teton County',
#  '16083': 'Twin Falls County',
#  '16085': 'Valley County',
#  '16087': 'Washington County',
#  '17001': 'Adams County',
#  '17003': 'Alexander County',
#  '17005': 'Bond County',
#  '17007': 'Boone County',
#  '17009': 'Brown County',
#  '17011': 'Bureau County',
#  '17013': 'Calhoun County',
#  '17015': 'Carroll County',
#  '17017': 'Cass County',
#  '17019': 'Champaign County',
#  '17021': 'Christian County',
#  '17023': 'Clark County',
#  '17025': 'Clay County',
#  '17027': 'Clinton County',
#  '17029': 'Coles County',
#  '17031': 'Cook County',
#  '17033': 'Crawford County',
#  '17035': 'Cumberland County',
#  '17037': 'DeKalb County',
#  '17039': 'De Witt County',
#  '17041': 'Douglas County',
#  '17043': 'DuPage County',
#  '17045': 'Edgar County',
#  '17047': 'Edwards County',
#  '17049': 'Effingham County',
#  '17051': 'Fayette County',
#  '17053': 'Ford County',
#  '17055': 'Franklin County',
#  '17057': 'Fulton County',
#  '17059': 'Gallatin County',
#  '17061': 'Greene County',
#  '17063': 'Grundy County',
#  '17065': 'Hamilton County',
#  '17067': 'Hancock County',
#  '17069': 'Hardin County',
#  '17071': 'Henderson County',
#  '17073': 'Henry County',
#  '17075': 'Iroquois County',
#  '17077': 'Jackson County',
#  '17079': 'Jasper County',
#  '17081': 'Jefferson County',
#  '17083': 'Jersey County',
#  '17085': 'Jo Daviess County',
#  '17087': 'Johnson County',
#  '17089': 'Kane County',
#  '17091': 'Kankakee County',
#  '17093': 'Kendall County',
#  '17095': 'Knox County',
#  '17097': 'Lake County',
#  '17099': 'LaSalle County',
#  '17101': 'Lawrence County',
#  '17103': 'Lee County',
#  '17105': 'Livingston County',
#  '17107': 'Logan County',
#  '17109': 'McDonough County',
#  '17111': 'McHenry County',
#  '17113': 'McLean County',
#  '17115': 'Macon County',
#  '17117': 'Macoupin County',
#  '17119': 'Madison County',
#  '17121': 'Marion County',
#  '17123': 'Marshall County',
#  '17125': 'Mason County',
#  '17127': 'Massac County',
#  '17129': 'Menard County',
#  '17131': 'Mercer County',
#  '17133': 'Monroe County',
#  '17135': 'Montgomery County',
#  '17137': 'Morgan County',
#  '17139': 'Moultrie County',
#  '17141': 'Ogle County',
#  '17143': 'Peoria County',
#  '17145': 'Perry County',
#  '17147': 'Piatt County',
#  '17149': 'Pike County',
#  '17151': 'Pope County',
#  '17153': 'Pulaski County',
#  '17155': 'Putnam County',
#  '17157': 'Randolph County',
#  '17159': 'Richland County',
#  '17161': 'Rock Island County',
#  '17163': 'St. Clair County',
#  '17165': 'Saline County',
#  '17167': 'Sangamon County',
#  '17169': 'Schuyler County',
#  '17171': 'Scott County',
#  '17173': 'Shelby County',
#  '17175': 'Stark County',
#  '17177': 'Stephenson County',
#  '17179': 'Tazewell County',
#  '17181': 'Union County',
#  '17183': 'Vermilion County',
#  '17185': 'Wabash County',
#  '17187': 'Warren County',
#  '17189': 'Washington County',
#  '17191': 'Wayne County',
#  '17193': 'White County',
#  '17195': 'Whiteside County',
#  '17197': 'Will County',
#  '17199': 'Williamson County',
#  '17201': 'Winnebago County',
#  '17203': 'Woodford County',
#  '18001': 'Adams County',
#  '18003': 'Allen County',
#  '18005': 'Bartholomew County',
#  '18007': 'Benton County',
#  '18009': 'Blackford County',
#  '18011': 'Boone County',
#  '18013': 'Brown County',
#  '18015': 'Carroll County',
#  '18017': 'Cass County',
#  '18019': 'Clark County',
#  '18021': 'Clay County',
#  '18023': 'Clinton County',
#  '18025': 'Crawford County',
#  '18027': 'Daviess County',
#  '18029': 'Dearborn County',
#  '18031': 'Decatur County',
#  '18033': 'DeKalb County',
#  '18035': 'Delaware County',
#  '18037': 'Dubois County',
#  '18039': 'Elkhart County',
#  '18041': 'Fayette County',
#  '18043': 'Floyd County',
#  '18045': 'Fountain County',
#  '18047': 'Franklin County',
#  '18049': 'Fulton County',
#  '18051': 'Gibson County',
#  '18053': 'Grant County',
#  '18055': 'Greene County',
#  '18057': 'Hamilton County',
#  '18059': 'Hancock County',
#  '18061': 'Harrison County',
#  '18063': 'Hendricks County',
#  '18065': 'Henry County',
#  '18067': 'Howard County',
#  '18069': 'Huntington County',
#  '18071': 'Jackson County',
#  '18073': 'Jasper County',
#  '18075': 'Jay County',
#  '18077': 'Jefferson County',
#  '18079': 'Jennings County',
#  '18081': 'Johnson County',
#  '18083': 'Knox County',
#  '18085': 'Kosciusko County',
#  '18087': 'LaGrange County',
#  '18089': 'Lake County',
#  '18091': 'LaPorte County',
#  '18093': 'Lawrence County',
#  '18095': 'Madison County',
#  '18097': 'Marion County',
#  '18099': 'Marshall County',
#  '18101': 'Martin County',
#  '18103': 'Miami County',
#  '18105': 'Monroe County',
#  '18107': 'Montgomery County',
#  '18109': 'Morgan County',
#  '18111': 'Newton County',
#  '18113': 'Noble County',
#  '18115': 'Ohio County',
#  '18117': 'Orange County',
#  '18119': 'Owen County',
#  '18121': 'Parke County',
#  '18123': 'Perry County',
#  '18125': 'Pike County',
#  '18127': 'Porter County',
#  '18129': 'Posey County',
#  '18131': 'Pulaski County',
#  '18133': 'Putnam County',
#  '18135': 'Randolph County',
#  '18137': 'Ripley County',
#  '18139': 'Rush County',
#  '18141': 'St. Joseph County',
#  '18143': 'Scott County',
#  '18145': 'Shelby County',
#  '18147': 'Spencer County',
#  '18149': 'Starke County',
#  '18151': 'Steuben County',
#  '18153': 'Sullivan County',
#  '18155': 'Switzerland County',
#  '18157': 'Tippecanoe County',
#  '18159': 'Tipton County',
#  '18161': 'Union County',
#  '18163': 'Vanderburgh County',
#  '18165': 'Vermillion County',
#  '18167': 'Vigo County',
#  '18169': 'Wabash County',
#  '18171': 'Warren County',
#  '18173': 'Warrick County',
#  '18175': 'Washington County',
#  '18177': 'Wayne County',
#  '18179': 'Wells County',
#  '18181': 'White County',
#  '18183': 'Whitley County',
#  '19001': 'Adair County',
#  '19003': 'Adams County',
#  '19005': 'Allamakee County',
#  '19007': 'Appanoose County',
#  '19009': 'Audubon County',
#  '19011': 'Benton County',
#  '19013': 'Black Hawk County',
#  '19015': 'Boone County',
#  '19017': 'Bremer County',
#  '19019': 'Buchanan County',
#  '19021': 'Buena Vista County',
#  '19023': 'Butler County',
#  '19025': 'Calhoun County',
#  '19027': 'Carroll County',
#  '19029': 'Cass County',
#  '19031': 'Cedar County',
#  '19033': 'Cerro Gordo County',
#  '19035': 'Cherokee County',
#  '19037': 'Chickasaw County',
#  '19039': 'Clarke County',
#  '19041': 'Clay County',
#  '19043': 'Clayton County',
#  '19045': 'Clinton County',
#  '19047': 'Crawford County',
#  '19049': 'Dallas County',
#  '19051': 'Davis County',
#  '19053': 'Decatur County',
#  '19055': 'Delaware County',
#  '19057': 'Des Moines County',
#  '19059': 'Dickinson County',
#  '19061': 'Dubuque County',
#  '19063': 'Emmet County',
#  '19065': 'Fayette County',
#  '19067': 'Floyd County',
#  '19069': 'Franklin County',
#  '19071': 'Fremont County',
#  '19073': 'Greene County',
#  '19075': 'Grundy County',
#  '19077': 'Guthrie County',
#  '19079': 'Hamilton County',
#  '19081': 'Hancock County',
#  '19083': 'Hardin County',
#  '19085': 'Harrison County',
#  '19087': 'Henry County',
#  '19089': 'Howard County',
#  '19091': 'Humboldt County',
#  '19093': 'Ida County',
#  '19095': 'Iowa County',
#  '19097': 'Jackson County',
#  '19099': 'Jasper County',
#  '19101': 'Jefferson County',
#  '19103': 'Johnson County',
#  '19105': 'Jones County',
#  '19107': 'Keokuk County',
#  '19109': 'Kossuth County',
#  '19111': 'Lee County',
#  '19113': 'Linn County',
#  '19115': 'Louisa County',
#  '19117': 'Lucas County',
#  '19119': 'Lyon County',
#  '19121': 'Madison County',
#  '19123': 'Mahaska County',
#  '19125': 'Marion County',
#  '19127': 'Marshall County',
#  '19129': 'Mills County',
#  '19131': 'Mitchell County',
#  '19133': 'Monona County',
#  '19135': 'Monroe County',
#  '19137': 'Montgomery County',
#  '19139': 'Muscatine County',
#  '19141': "O'Brien County",
#  '19143': 'Osceola County',
#  '19145': 'Page County',
#  '19147': 'Palo Alto County',
#  '19149': 'Plymouth County',
#  '19151': 'Pocahontas County',
#  '19153': 'Polk County',
#  '19155': 'Pottawattamie County',
#  '19157': 'Poweshiek County',
#  '19159': 'Ringgold County',
#  '19161': 'Sac County',
#  '19163': 'Scott County',
#  '19165': 'Shelby County',
#  '19167': 'Sioux County',
#  '19169': 'Story County',
#  '19171': 'Tama County',
#  '19173': 'Taylor County',
#  '19175': 'Union County',
#  '19177': 'Van Buren County',
#  '19179': 'Wapello County',
#  '19181': 'Warren County',
#  '19183': 'Washington County',
#  '19185': 'Wayne County',
#  '19187': 'Webster County',
#  '19189': 'Winnebago County',
#  '19191': 'Winneshiek County',
#  '19193': 'Woodbury County',
#  '19195': 'Worth County',
#  '19197': 'Wright County',
#  '20001': 'Allen County',
#  '20003': 'Anderson County',
#  '20005': 'Atchison County',
#  '20007': 'Barber County',
#  '20009': 'Barton County',
#  '20011': 'Bourbon County',
#  '20013': 'Brown County',
#  '20015': 'Butler County',
#  '20017': 'Chase County',
#  '20019': 'Chautauqua County',
#  '20021': 'Cherokee County',
#  '20023': 'Cheyenne County',
#  '20025': 'Clark County',
#  '20027': 'Clay County',
#  '20029': 'Cloud County',
#  '20031': 'Coffey County',
#  '20033': 'Comanche County',
#  '20035': 'Cowley County',
#  '20037': 'Crawford County',
#  '20039': 'Decatur County',
#  '20041': 'Dickinson County',
#  '20043': 'Doniphan County',
#  '20045': 'Douglas County',
#  '20047': 'Edwards County',
#  '20049': 'Elk County',
#  '20051': 'Ellis County',
#  '20053': 'Ellsworth County',
#  '20055': 'Finney County',
#  '20057': 'Ford County',
#  '20059': 'Franklin County',
#  '20061': 'Geary County',
#  '20063': 'Gove County',
#  '20065': 'Graham County',
#  '20067': 'Grant County',
#  '20069': 'Gray County',
#  '20071': 'Greeley County',
#  '20073': 'Greenwood County',
#  '20075': 'Hamilton County',
#  '20077': 'Harper County',
#  '20079': 'Harvey County',
#  '20081': 'Haskell County',
#  '20083': 'Hodgeman County',
#  '20085': 'Jackson County',
#  '20087': 'Jefferson County',
#  '20089': 'Jewell County',
#  '20091': 'Johnson County',
#  '20093': 'Kearny County',
#  '20095': 'Kingman County',
#  '20097': 'Kiowa County',
#  '20099': 'Labette County',
#  '20101': 'Lane County',
#  '20103': 'Leavenworth County',
#  '20105': 'Lincoln County',
#  '20107': 'Linn County',
#  '20109': 'Logan County',
#  '20111': 'Lyon County',
#  '20113': 'McPherson County',
#  '20115': 'Marion County',
#  '20117': 'Marshall County',
#  '20119': 'Meade County',
#  '20121': 'Miami County',
#  '20123': 'Mitchell County',
#  '20125': 'Montgomery County',
#  '20127': 'Morris County',
#  '20129': 'Morton County',
#  '20131': 'Nemaha County',
#  '20133': 'Neosho County',
#  '20135': 'Ness County',
#  '20137': 'Norton County',
#  '20139': 'Osage County',
#  '20141': 'Osborne County',
#  '20143': 'Ottawa County',
#  '20145': 'Pawnee County',
#  '20147': 'Phillips County',
#  '20149': 'Pottawatomie County',
#  '20151': 'Pratt County',
#  '20153': 'Rawlins County',
#  '20155': 'Reno County',
#  '20157': 'Republic County',
#  '20159': 'Rice County',
#  '20161': 'Riley County',
#  '20163': 'Rooks County',
#  '20165': 'Rush County',
#  '20167': 'Russell County',
#  '20169': 'Saline County',
#  '20171': 'Scott County',
#  '20173': 'Sedgwick County',
#  '20175': 'Seward County',
#  '20177': 'Shawnee County',
#  '20179': 'Sheridan County',
#  '20181': 'Sherman County',
#  '20183': 'Smith County',
#  '20185': 'Stafford County',
#  '20187': 'Stanton County',
#  '20189': 'Stevens County',
#  '20191': 'Sumner County',
#  '20193': 'Thomas County',
#  '20195': 'Trego County',
#  '20197': 'Wabaunsee County',
#  '20199': 'Wallace County',
#  '20201': 'Washington County',
#  '20203': 'Wichita County',
#  '20205': 'Wilson County',
#  '20207': 'Woodson County',
#  '20209': 'Wyandotte County',
#  '21001': 'Adair County',
#  '21003': 'Allen County',
#  '21005': 'Anderson County',
#  '21007': 'Ballard County',
#  '21009': 'Barren County',
#  '21011': 'Bath County',
#  '21013': 'Bell County',
#  ...}

# %%
#Finding number of "Charter Township" Labels to see if this accounts for discrepency (Charter does not appear in df)

#bool_array = gdf.Label.str.contains('Charter')
#count = np.count_nonzero(bool_array)
#print(count)

#Mask to remove "Charter" rows from dataset
remove_charter = gdf[(gdf.Label != 'Charter')]
remove_charter
#did not work to remove^
# Out:
#       OBJECTID    Id        VTD2016 CountyFips Jurisdicti  ElectionYe  \
# 0            1  3888  1632100000001        163      21000        2016
# 1            2  3889  1632100000002        163      21000        2016
# 2            3  3890  1632100000003        163      21000        2016
# 3            4  3891  1632100000004        163      21000        2016
# 4            5  3892  1632100000005        163      21000        2016
# ...        ...   ...            ...        ...        ...         ...
# 4805      4806  1805  0933186000007        093      31860        2016
# 4806      4807  1848  0936012000005        093      60120        2016
# 4807      4808  1848  0936012000001        093      60120        2016
# 4808      4809  1848  0936012000002        093      60120        2016
# 4809      4810  1848  0936012000004        093      60120        2016
#
#                  Label    ShapeSTAre    ShapeSTLen  \
# 0     City of Dearborn  2.489738e+06   6846.254657
# 1     City of Dearborn  1.058362e+06   4621.388992
# 2     City of Dearborn  1.488846e+06   4909.715171
# 3     City of Dearborn  1.187165e+06   4354.743602
# 4     City of Dearborn  1.133548e+06   5460.202887
# ...                ...           ...           ...
# 4805    Genoa Township  6.610719e+06  18986.630070
# 4806   Oceola Township  8.526046e+06  12408.612226
# 4807   Oceola Township  4.258013e+07  28101.267509
# 4808   Oceola Township  7.200447e+06  13280.921753
# 4809   Oceola Township  5.494319e+07  60109.459882
#
#                                                geometry precinct_number  \
# 0     POLYGON ((734740.564 203392.197, 734729.230 20...               1
# 1     POLYGON ((733757.240 203553.421, 733767.280 20...               2
# 2     POLYGON ((733220.680 203094.269, 733125.455 20...               3
# 3     POLYGON ((732401.480 203234.816, 732303.854 20...               4
# 4     POLYGON ((731590.226 203387.835, 731604.080 20...               5
# ...                                                 ...             ...
# 4805  POLYGON ((678019.208 220453.671, 677984.088 22...               7
# 4806  POLYGON ((674226.582 230029.619, 674205.136 23...               5
# 4807  POLYGON ((674058.491 233218.627, 673972.280 23...               1
# 4808  POLYGON ((672258.795 232398.214, 672291.130 23...               2
# 4809  MULTIPOLYGON (((680045.558 239973.034, 680132....               4
#
#      ward_number
# 0
# 1
# 2
# 3
# 4
# ...          ...
# 4805
# 4806
# 4807
# 4808
# 4809
#
# [4810 rows x 12 columns]

# %%
mask = gdf[gdf.CountyFips == '005']
mask
#precincts_shp_2016[(precincts_shp_2016.CountyFips == "005")
# Out:
#      OBJECTID  Id        VTD2016 CountyFips Jurisdicti  ElectionYe  \
# 69         70  24  0050126000001        005      01260        2016
# 70         71  25  0050126000002        005      01260        2016
# 71         72  26  0050128000001        005      01280        2016
# 72         73  27  0050128000002        005      01280        2016
# 73         74  28  0051370000001        005      13700        2016
# 74         75  29  0051520000001        005      15200        2016
# 75         76  30  0051672000001        005      16720        2016
# 76         77  31  0052268000001        005      22680        2016
# 77         78  32  0052268000002        005      22680        2016
# 78         79  33  0052268000003        005      22680        2016
# 79         80  34  0052274000001        005      22740        2016
# 80         81  35  0052774000001        005      27740        2016
# 81         82  36  0052812000001        005      28120        2016
# 82         83  37  0053136000001        005      31360        2016
# 83         84  38  0053572000001        005      35720        2016
# 84         85  39  0053572000002        005      35720        2016
# 85         86  40  0053746000001        005      37460        2016
# 86         87  41  0053864004009        005      38640        2016
# 87         88  42  0053864005011        005      38640        2016
# 88         89  43  0053864005012        005      38640        2016
# 89         90  44  0053864005013        005      38640        2016
# 90         91  45  0053920000001        005      39200        2016
# 91         92  46  0054518000001        005      45180        2016
# 92         93  47  0054518000002        005      45180        2016
# 93         94  48  0054518000003        005      45180        2016
# 94         95  49  0054660000001        005      46600        2016
# 95         96  50  0054676000001        005      46760        2016
# 96         97  51  0054676000002        005      46760        2016
# 97         98  52  0055084000001        005      50840        2016
# 98         99  53  0055200000001        005      52000        2016
# 99        100  54  0055520000001        005      55200        2016
# 100       101  55  0056162000001        005      61620        2016
# 101       102  56  0056164000001        005      61640        2016
# 102       103  57  0056164000002        005      61640        2016
# 103       104  58  0056182000001        005      61820        2016
# 104       105  59  0056474000001        005      64740        2016
# 105       106  60  0057110000001        005      71100        2016
# 106       107  61  0057110000002        005      71100        2016
# 107       108  62  0057170000001        005      71700        2016
# 108       109  63  0057172000001        005      71720        2016
# 109       110  64  0057498003002        005      74980        2016
# 110       111  65  0058062000001        005      80620        2016
# 111       112  66  0058158000001        005      81580        2016
# 112       113  67  0058458000001        005      84580        2016
# 113       114  68  0058488000001        005      84880        2016
# 114       115  69  0058490000001        005      84900        2016
#
#                           Label    ShapeSTAre    ShapeSTLen  \
# 69              City of Allegan  1.520515e+07  27763.275509
# 70              City of Allegan  5.126924e+06  12777.389783
# 71             Allegan Township  8.792993e+07  55171.527066
# 72             Allegan Township  6.431700e+07  42518.946276
# 73               Casco Township  1.854138e+08  57308.570654
# 74            Cheshire Township  1.710239e+08  52288.791305
# 75               Clyde Township  1.694473e+08  56756.648215
# 76                Dorr Township  7.795300e+07  51958.292997
# 77                Dorr Township  5.915112e+07  36266.044779
# 78                Dorr Township  3.659305e+07  31549.257669
# 79   City of Village of Douglas  9.433910e+06  15456.829333
# 80            City of Fennville  5.299730e+06  12500.580420
# 81            Fillmore Township  1.362277e+08  69196.282404
# 82              Ganges Township  1.560779e+08  49985.690870
# 83            Gunplain Township  7.791787e+07  59550.242227
# 84            Gunplain Township  8.576802e+07  40627.861436
# 85               Heath Township  1.719723e+08  52481.386631
# 86              City of Holland  3.155785e+06  13267.491504
# 87              City of Holland  2.840689e+07  30999.625997
# 88              City of Holland  2.238390e+06   6415.478016
# 89              City of Holland  5.903689e+06  15316.262793
# 90             Hopkins Township  1.724977e+08  52567.266415
# 91            Laketown Township  1.509073e+07  20603.521311
# 92            Laketown Township  5.089204e+07  51813.719838
# 93            Laketown Township  3.798536e+07  40481.392373
# 94                 Lee Township  1.719148e+08  52497.541780
# 95            Leighton Township  1.113760e+08  64226.411798
# 96            Leighton Township  5.955208e+07  59225.315401
# 97             Manlius Township  1.721728e+08  56309.071718
# 98              Martin Township  1.717703e+08  52558.333990
# 99            Monterey Township  1.723526e+08  52549.485929
# 100              City of Otsego  1.016088e+07  23122.824306
# 101             Otsego Township  1.100372e+08  51484.410437
# 102             Otsego Township  5.119968e+07  44429.658000
# 103           Overisel Township  1.715354e+08  52365.340159
# 104           City of Plainwell  9.808039e+06  20101.098017
# 105              Salem Township  9.863779e+07  48603.736760
# 106              Salem Township  7.439157e+07  48525.538745
# 107           City of Saugatuck  7.032032e+06  12158.577086
# 108          Saugatuck Township  1.159782e+08  57887.731006
# 109         City of South Haven  1.697711e+05   1881.842376
# 110         Trowbridge Township  1.704626e+08  52276.994105
# 111             Valley Township  1.718050e+08  52463.743161
# 112             Watson Township  1.723700e+08  52393.124290
# 113             City of Wayland  1.449016e+07  19750.111589
# 114            Wayland Township  1.600706e+08  59944.183264
#
#                                               geometry precinct_number  \
# 69   POLYGON ((513778.494 222001.410, 513410.908 22...               1
# 70   POLYGON ((511376.262 220097.564, 511404.104 22...               2
# 71   POLYGON ((513766.037 222228.599, 513480.905 22...               1
# 72   POLYGON ((518018.119 217487.315, 516998.501 21...               2
# 73   POLYGON ((489265.070 207602.820, 489221.697 20...               1
# 74   POLYGON ((500011.164 217310.299, 500401.976 21...               1
# 75   POLYGON ((494530.832 227057.587, 494565.707 22...               1
# 76   POLYGON ((521024.096 246411.890, 520975.630 24...               1
# 77   POLYGON ((527423.801 246417.851, 527425.297 24...               2
# 78   POLYGON ((522634.673 241622.366, 522735.468 24...               3
# 79   POLYGON ((484087.461 232766.372, 484392.680 23...               1
# 80   POLYGON ((492115.691 227255.668, 492252.064 22...               1
# 81   POLYGON ((497571.780 246445.548, 498389.380 24...               1
# 82   POLYGON ((489234.436 217292.045, 487636.929 21...               1
# 83   POLYGON ((534244.775 212950.486, 534578.817 21...               1
# 84   POLYGON ((536199.913 217679.296, 536230.421 21...               2
# 85   POLYGON ((499644.718 236773.133, 499693.473 23...               1
# 86   MULTIPOLYGON (((490317.332 246396.314, 490311....               9
# 87   POLYGON ((490344.226 243212.006, 490320.279 24...              11
# 88   POLYGON ((491929.154 245666.028, 491705.412 24...              12
# 89   POLYGON ((491140.579 245220.905, 491143.219 24...              13
# 90   POLYGON ((524907.042 236766.807, 525222.257 23...               1
# 91   POLYGON ((486628.553 245954.685, 486636.281 24...               1
# 92   POLYGON ((485970.777 238690.613, 485984.309 23...               2
# 93   MULTIPOLYGON (((485954.243 238748.727, 485984....               3
# 94   POLYGON ((497221.246 217318.954, 498025.469 21...               1
# 95   POLYGON ((530182.748 245441.179, 530191.746 24...               1
# 96   POLYGON ((537149.605 236842.132, 537067.669 23...               2
# 97   POLYGON ((498664.130 236797.969, 498663.099 23...               1
# 98   POLYGON ((537423.010 217677.125, 537319.580 21...               1
# 99   POLYGON ((517853.697 227134.653, 517078.502 22...               1
# 100  POLYGON ((524476.328 213073.123, 524961.261 21...               1
# 101  POLYGON ((524476.328 213073.123, 524171.951 21...               1
# 102  MULTIPOLYGON (((527734.745 212461.548, 527722....               2
# 103  POLYGON ((507939.811 246312.482, 507955.987 24...               1
# 104  POLYGON ((529676.983 212021.719, 529682.260 21...               1
# 105  POLYGON ((511415.326 236689.920, 511393.613 23...               1
# 106  POLYGON ((517686.594 245674.272, 517695.544 24...               2
# 107  POLYGON ((484087.461 232766.372, 483941.697 23...               1
# 108  POLYGON ((488974.324 227032.827, 488579.611 22...               1
# 109  POLYGON ((478478.130 207640.709, 478367.035 20...               2
# 110  POLYGON ((518146.812 207798.730, 518057.619 20...               1
# 111  POLYGON ((500159.538 227003.786, 500921.030 22...               1
# 112  POLYGON ((519657.942 227160.743, 519825.170 22...               1
# 113  POLYGON ((531124.758 236797.447, 531131.698 23...               1
# 114  POLYGON ((537149.605 236842.132, 537152.716 23...               1
#
#     ward_number
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86            4
# 87            5
# 88            5
# 89            5
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109           3
# 110
# 111
# 112
# 113
# 114

# %%
#lambda is anonymous fxn - can only use in the one spot. get_ward is nicer to use, but lambda can be used for qui
foo.VTD2016.apply(lambda VTD2016:VTD2016[-5:-3])
# Out:
# 86    04
# 87    05
# 88    05
# 89    05
# Name: VTD2016, dtype: object

# %%
precincts_shp_2016.Id.nunique()
# Out:
# 4769

# %%
precincts_shp_2016.Label
# Out:
# 0       City of Dearborn
# 1       City of Dearborn
# 2       City of Dearborn
# 3       City of Dearborn
# 4       City of Dearborn
#               ...
# 4805      Genoa Township
# 4806     Oceola Township
# 4807     Oceola Township
# 4808     Oceola Township
# 4809     Oceola Township
# Name: Label, Length: 4810, dtype: object

# %%
precincts_shp_2016.VTD2016
# Out:
# 0       1632100000001
# 1       1632100000002
# 2       1632100000003
# 3       1632100000004
# 4       1632100000005
#             ...
# 4805    0933186000007
# 4806    0936012000005
# 4807    0936012000001
# 4808    0936012000002
# 4809    0936012000004
# Name: VTD2016, Length: 4810, dtype: object

# %%
precincts_shp_2016.CountyFips
# Out:
# 0       163
# 1       163
# 2       163
# 3       163
# 4       163
#        ...
# 4805    093
# 4806    093
# 4807    093
# 4808    093
# 4809    093
# Name: CountyFips, Length: 4810, dtype: object

# %% [markdown]
# Data Files/dataframe (df)

# %%
#2016 precinct-level election data - all offices all states
precinct_election_data = pd.read_csv("2016-precinct-president.csv", 
                                     encoding='ISO-8859-1',
                                     dtype = {"county_name" : "str","precinct" : "str","district" : "str"},
                                    low_memory=False)
#specified datatype for specific columns due to error message

# %%
precinct_election_data.head()
# Out:
#    year stage  special    state state_postal  state_fips  state_icpsr  \
# 0  2016   gen    False  Alabama           AL           1           41
# 1  2016   gen    False  Alabama           AL           1           41
# 2  2016   gen    False  Alabama           AL           1           41
# 3  2016   gen    False  Alabama           AL           1           41
# 4  2016   gen    False  Alabama           AL           1           41
#
#       county_name  county_fips  county_ansi  ...  candidate_middle  \
# 0  Autauga County       1001.0     161526.0  ...               NaN
# 1  Autauga County       1001.0     161526.0  ...               NaN
# 2  Autauga County       1001.0     161526.0  ...               NaN
# 3  Autauga County       1001.0     161526.0  ...               NaN
# 4  Autauga County       1001.0     161526.0  ...               NaN
#
#    candidate_full candidate_suffix candidate_nickname candidate_fec  \
# 0             NaN              NaN                NaN     P00003392
# 1             NaN              NaN                NaN     P60012234
# 2             NaN              NaN                NaN     P20003984
# 3             NaN              NaN                NaN     P80001571
# 4             NaN              NaN                NaN           NaN
#
#                                 candidate_fec_name candidate_google  \
# 0  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE              NaN
# 1                     JOHNSON, JOHN FITZGERALD MR.              NaN
# 2                                      STEIN, JILL              NaN
# 3              TRUMP, DONALD J. / MICHAEL R. PENCE              NaN
# 4                                              NaN              NaN
#
#   candidate_govtrack  candidate_icpsr candidate_maplight
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
# 2                NaN              NaN                NaN
# 3                NaN              NaN                NaN
# 4                NaN              NaN                NaN
#
# [5 rows x 37 columns]

# %%
#Filter to return data only for MI
mi_precinct_election = precinct_election_data[precinct_election_data.state_fips == 26]

# %%
#mi_precinct_election.head()

# %%
#mi_precinct_election.nunique()

# %%
#Number of unique precincts in each county 
foo = mi_precinct_election.groupby('county_name').precinct.nunique()
foo
#foo is a variable used to represent and unspecified entity
# Out:
# county_name
# Alcona County         13
# Alger County          11
# Allegan County        46
# Alpena County         18
# Antrim County         17
#                     ...
# Tuscola County        32
# Van Buren County      34
# Washtenaw County     142
# Wayne County        1172
# Wexford County        21
# Name: precinct, Length: 83, dtype: int64

# %%
foo.sum()
# Out:
# 5077

# %%
mi_precinct_election.office.unique()
# Out:
# array(['US President'], dtype=object)

# %%
#I included this because CG did before... we filter out the other 2 parties to match MGGG?
mi_party = mi_precinct_election[
    (mi_precinct_election.party == 'democratic')|
    (mi_precinct_election.party == 'republican')|
    (mi_precinct_election.party == 'libertarian')|
    (mi_precinct_election.party == 'green')]

# %%
df = mi_pivot = mi_party.pivot_table(index = ['county_name','precinct'],
                         columns = ['party'],
                        values = ['votes'],
                         aggfunc = 'sum').reset_index()
#"reset_index" turns assigned indices into columns so that mask can be applied

# %%
mask = df[df.precinct == "Statistical Adjustments"]
mask.shape
# Out:
# (56, 6)

# %%
#get rid of "statistical adjustment" rows
is_statistical_adjustment_mask = (df.precinct == "Statistical Adjustments")
#make opposite of above argument
~is_statistical_adjustment_mask
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5072     True
# 5073     True
# 5074     True
# 5075    False
# 5076     True
# Name: precinct, Length: 5077, dtype: bool

# %%
#mask to remove statistical adjustment - filter on false
remove_stat_adjust = df[(df.precinct != 'Statistical Adjustments')]
remove_stat_adjust
# Out:
#           county_name                  precinct      votes                    \
# party                                           democratic green libertarian
# 0       Alcona County        ALCONA TOWNSHIP; 1        199     2          13
# 1       Alcona County     CALEDONIA TOWNSHIP; 1        178     4          14
# 2       Alcona County        CURTIS TOWNSHIP; 1        214    13           8
# 3       Alcona County     GREENBUSH TOWNSHIP; 1        256     4          22
# 4       Alcona County        GUSTIN TOWNSHIP; 1         80     6          16
# ...               ...                       ...        ...   ...         ...
# 5071   Wexford County         SELMA TOWNSHIP; 1        322    14          36
# 5072   Wexford County        SLAGLE TOWNSHIP; 1         92     0          12
# 5073   Wexford County  SOUTH BRANCH TOWNSHIP; 1         76     3           5
# 5074   Wexford County   SPRINGVILLE TOWNSHIP; 1        176    10          28
# 5076   Wexford County       WEXFORD TOWNSHIP; 1        110     7          17
#
#
# party republican
# 0            500
# 1            441
# 2            401
# 3            501
# 4            249
# ...          ...
# 5071         729
# 5072         179
# 5073         127
# 5074         494
# 5076         357
#
# [5021 rows x 6 columns]

# %%
df.head(55)
# Out:
#           county_name                              precinct      votes        \
# party                                                       democratic green
# 0       Alcona County                    ALCONA TOWNSHIP; 1        199     2
# 1       Alcona County                 CALEDONIA TOWNSHIP; 1        178     4
# 2       Alcona County                    CURTIS TOWNSHIP; 1        214    13
# 3       Alcona County                 GREENBUSH TOWNSHIP; 1        256     4
# 4       Alcona County                    GUSTIN TOWNSHIP; 1         80     6
# 5       Alcona County  HARRISVILLE CITY; Ward 1; Precinct 1         98     4
# 6       Alcona County               HARRISVILLE TOWNSHIP; 1        216     6
# 7       Alcona County                     HAWES TOWNSHIP; 1        160     4
# 8       Alcona County                    HAYNES TOWNSHIP; 1        121     3
# 9       Alcona County                    MIKADO TOWNSHIP; 1         96     4
# 10      Alcona County                    MILLEN TOWNSHIP; 1         72     3
# 11      Alcona County                  MITCHELL TOWNSHIP; 1         42     1
# 12      Alcona County               Statistical Adjustments          0     0
# 13       Alger County                  AU TRAIN TOWNSHIP; 1        199     6
# 14       Alger County                      BURT TOWNSHIP; 1        101     6
# 15       Alger County              GRAND ISLAND TOWNSHIP; 1         15     0
# 16       Alger County                 LIMESTONE TOWNSHIP; 1         75     3
# 17       Alger County                   MATHIAS TOWNSHIP; 1        111     3
# 18       Alger County                      MUNISING CITY; 1        441    23
# 19       Alger County                  MUNISING TOWNSHIP; 1        166     6
# 20       Alger County                  MUNISING TOWNSHIP; 2        158     6
# 21       Alger County                     ONOTA TOWNSHIP; 1        121     4
# 22       Alger County                ROCK RIVER TOWNSHIP; 1        276    10
# 23       Alger County               Statistical Adjustments          0     0
# 24     Allegan County                       ALLEGAN CITY; 1        283    10
# 25     Allegan County                       ALLEGAN CITY; 2        475    32
# 26     Allegan County                   ALLEGAN TOWNSHIP; 1        554    10
# 27     Allegan County                   ALLEGAN TOWNSHIP; 2        209     7
# 28     Allegan County                     CASCO TOWNSHIP; 1        605     8
# 29     Allegan County                  CHESHIRE TOWNSHIP; 1        290    13
# 30     Allegan County                     CLYDE TOWNSHIP; 1        310     6
# 31     Allegan County                      DORR TOWNSHIP; 1        261     7
# 32     Allegan County                      DORR TOWNSHIP; 2        348    22
# 33     Allegan County                      DORR TOWNSHIP; 3        330    14
# 34     Allegan County                       DOUGLAS CITY; 1        528     6
# 35     Allegan County                     FENNVILLE CITY; 1        204    10
# 36     Allegan County                  FILLMORE TOWNSHIP; 1        227    10
# 37     Allegan County                    GANGES TOWNSHIP; 1        602    13
# 38     Allegan County                  GUNPLAIN TOWNSHIP; 1        743    25
# 39     Allegan County                  GUNPLAIN TOWNSHIP; 2        445    11
# 40     Allegan County                     HEATH TOWNSHIP; 1        348    17
# 41     Allegan County      HOLLAND CITY; Ward 4; Precinct 9        370    18
# 42     Allegan County     HOLLAND CITY; Ward 5; Precinct 11        316    12
# 43     Allegan County     HOLLAND CITY; Ward 5; Precinct 12        312    10
# 44     Allegan County     HOLLAND CITY; Ward 5; Precinct 13        335     4
# 45     Allegan County                   HOPKINS TOWNSHIP; 1        306    17
# 46     Allegan County                  LAKETOWN TOWNSHIP; 1        523     6
# 47     Allegan County                  LAKETOWN TOWNSHIP; 2        459    14
# 48     Allegan County                  LAKETOWN TOWNSHIP; 3        254    11
# 49     Allegan County                       LEE TOWNSHIP; 1        381     7
# 50     Allegan County                  LEIGHTON TOWNSHIP; 1        410    14
# 51     Allegan County                  LEIGHTON TOWNSHIP; 2        202     5
# 52     Allegan County                   MANLIUS TOWNSHIP; 1        424    12
# 53     Allegan County                    MARTIN TOWNSHIP; 1        296     7
# 54     Allegan County                  MONTEREY TOWNSHIP; 1        256     9
#
#
# party libertarian republican
# 0              13        500
# 1              14        441
# 2               8        401
# 3              22        501
# 4              16        249
# 5              16        137
# 6              21        541
# 7              22        417
# 8              14        318
# 9              11        382
# 10              2        135
# 11              5        179
# 12              0          0
# 13             28        396
# 14             16        200
# 15              2          9
# 16              7        135
# 17             11        108
# 18             42        518
# 19             18        345
# 20             13        422
# 21             13        138
# 22             27        314
# 23              0          0
# 24             32        274
# 25             69        667
# 26             78        835
# 27             20        354
# 28             69        730
# 29             43        516
# 30             30        409
# 31             47        782
# 32             81       1163
# 33             58        810
# 34             17        245
# 35             28        229
# 36             39       1163
# 37             52        727
# 38             89       1009
# 39             66        648
# 40             70       1401
# 41             23        473
# 42             37        445
# 43             44        583
# 44             43        430
# 45             85        905
# 46             53        759
# 47             52       1151
# 48             22        342
# 49             39        521
# 50             80       1339
# 51             57        894
# 52             69       1141
# 53             63        839
# 54             52        748

# %%
df.shape
# Out:
# (5077, 6)

# %%
bool_array = df.precinct.str.contains('Charter')
count = np.count_nonzero(bool_array)

print(count)
# Out:
# 0

# %%
gdf
# Out:
#       OBJECTID    Id        VTD2016 CountyFips Jurisdicti  ElectionYe  \
# 0            1  3888  1632100000001        163      21000        2016
# 1            2  3889  1632100000002        163      21000        2016
# 2            3  3890  1632100000003        163      21000        2016
# 3            4  3891  1632100000004        163      21000        2016
# 4            5  3892  1632100000005        163      21000        2016
# ...        ...   ...            ...        ...        ...         ...
# 4805      4806  1805  0933186000007        093      31860        2016
# 4806      4807  1848  0936012000005        093      60120        2016
# 4807      4808  1848  0936012000001        093      60120        2016
# 4808      4809  1848  0936012000002        093      60120        2016
# 4809      4810  1848  0936012000004        093      60120        2016
#
#                  Label    ShapeSTAre    ShapeSTLen  \
# 0     City of Dearborn  2.489738e+06   6846.254657
# 1     City of Dearborn  1.058362e+06   4621.388992
# 2     City of Dearborn  1.488846e+06   4909.715171
# 3     City of Dearborn  1.187165e+06   4354.743602
# 4     City of Dearborn  1.133548e+06   5460.202887
# ...                ...           ...           ...
# 4805    Genoa Township  6.610719e+06  18986.630070
# 4806   Oceola Township  8.526046e+06  12408.612226
# 4807   Oceola Township  4.258013e+07  28101.267509
# 4808   Oceola Township  7.200447e+06  13280.921753
# 4809   Oceola Township  5.494319e+07  60109.459882
#
#                                                geometry precinct_number  \
# 0     POLYGON ((734740.564 203392.197, 734729.230 20...               1
# 1     POLYGON ((733757.240 203553.421, 733767.280 20...               2
# 2     POLYGON ((733220.680 203094.269, 733125.455 20...               3
# 3     POLYGON ((732401.480 203234.816, 732303.854 20...               4
# 4     POLYGON ((731590.226 203387.835, 731604.080 20...               5
# ...                                                 ...             ...
# 4805  POLYGON ((678019.208 220453.671, 677984.088 22...               7
# 4806  POLYGON ((674226.582 230029.619, 674205.136 23...               5
# 4807  POLYGON ((674058.491 233218.627, 673972.280 23...               1
# 4808  POLYGON ((672258.795 232398.214, 672291.130 23...               2
# 4809  MULTIPOLYGON (((680045.558 239973.034, 680132....               4
#
#      ward_number
# 0
# 1
# 2
# 3
# 4
# ...          ...
# 4805
# 4806
# 4807
# 4808
# 4809
#
# [4810 rows x 12 columns]

# %%
df.sum()
# Out:
#        party
# votes  democratic     2268839
#        green            51463
#        libertarian     172136
#        republican     2279543
# dtype: int64

# %%
df.shape
# Out:
# (5077, 4)

# %%
#Final MGGG Shapefile
mggg_final_shp = gpd.read_file("MI_precincts/MI_precincts.shp")
